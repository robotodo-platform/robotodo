# %%
import os

import nest_asyncio
nest_asyncio.apply()


import isaacsim
isaacsim.bootstrap_kernel()
from isaacsim.simulation_app import AppFramework



# TODO
experience = ""
if experience == "":
    # TODO use proper os.path.join
    for exp in [
        "isaacsim.exp.full.kit",
        "omni.isaac.sim.python.kit",
        "isaacsim.exp.base.python.kit",
        "isaacsim.exp.base.kit",
    ]:
        exp = os.path.join(os.environ["EXP_PATH"], exp)
        if os.path.isfile(exp):
            experience = exp
            break

exe_path = os.environ["CARB_APP_PATH"]

argv = [
    os.path.abspath(experience),
    # run as portable to prevent writing extra files to user directory
    "--portable",
    # extensions
    # extensions: adding to json doesn't work
    "--ext-folder", os.path.abspath(os.path.join(os.environ["ISAAC_PATH"], "exts")),
    # extensions: so we can reference other kit files  
    "--ext-folder", os.path.abspath(os.path.join(os.environ["ISAAC_PATH"], "apps")),      
    # ...      
    f"--/app/tokens/exe-path={os.path.abspath(exe_path)}",  # this is needed so dlss lib is found
    # "--/app/fastShutdown=true",
    "--/app/installSignalHandlers=false",
    "--/app/python/interceptSysStdOutput=false",
    "--/app/python/interceptSysExit=false",
    "--/app/python/logSysStdOutput=false",
    "--/app/python/enableGCProfiling=false",
    "--/app/python/disableGCDuringStartup=false",
    # logging
    # logging: disable default log file creation
    "--/log/file=",
    # "--/log/enabled=false",
    # *argv,
]

app_framework = AppFramework(argv=argv)
# Out:
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# Loading user config located at: '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/user.config.json'
# 2025-09-10T07:38:16Z s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.052s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.228s] [ext: omni.metrics.core-0.0.3] startup
# [0.229s] [ext: omni.client.lib-1.1.0] startup
# [0.242s] [ext: omni.blobkey-1.1.2] startup
# [0.242s] [ext: omni.stats-1.0.1] startup
# [0.243s] [ext: omni.datastore-0.0.0] startup
# [0.247s] [ext: omni.client-1.3.0] startup
# [0.303s] [ext: omni.ujitso.default-1.0.0] startup
# [0.304s] [ext: omni.hsscclient-1.1.2] startup
# [0.308s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.310s] [ext: omni.assets.plugins-0.0.0] startup
# [0.312s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.319s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.332s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 535.247.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3060          | Yes: 0 |     | 12288   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2504      | 3157457f.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 12 (bookworm) debian, Version: 12.00.0, Kernel: 6.1.0-35-amd64
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101007 (1.21.1.7)
# | Processor: 12th Gen Intel(R) Core(TM) i5-12400F
# | Cores: 6 | Logical Cores: 12
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 23868 | Free Memory: 14155
# | Total Page/Swap (MB): 16383 | Free Page/Swap: 13310
# |---------------------------------------------------------------------------------------------|
# 2025-09-10T07:38:17Z s] [Warning] [gpu.foundation.plugin] CPU performance profile is set to powersave. This profile sets the CPU to the lowest frequency reducing performance.
# 2025-09-10T07:38:17Z s] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# [0.860s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.861s] [ext: omni.materialx.libs-1.0.7] startup
# [0.869s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.870s] [ext: omni.usd.config-1.0.6] startup
# [0.872s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.872s] [ext: omni.usd.libs-1.0.1] startup
# [0.941s] [ext: omni.mdl-56.0.3] startup
# [1.046s] [ext: omni.iray.libs-0.0.0] startup
# [1.051s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [1.054s] [ext: omni.kit.usd.mdl-1.1.4] startup
# [1.135s] [ext: omni.kit.telemetry-0.5.2] startup
# [1.152s] [ext: omni.pip.compute-1.6.2] startup
# [1.153s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [1.154s] [ext: omni.kit.test-2.0.1] startup
# [1.192s] [ext: omni.appwindow-1.1.10] startup
# [1.687s] [ext: omni.kit.renderer.core-1.1.0] startup
# [6.190s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [6.192s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [6.257s] [ext: omni.ui-2.26.18] startup
# [6.265s] [ext: omni.kit.mainwindow-1.0.3] startup
# [6.266s] [ext: carb.audio-0.1.0] startup
# [6.269s] [ext: omni.uiaudio-1.0.0] startup
# [6.270s] [ext: omni.kit.uiapp-0.0.0] startup
# [6.270s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [6.271s] [ext: omni.usd.schema.audio-0.0.0] startup
# [6.274s] [ext: omni.usd.schema.isaac-3.0.5] startup
# [6.274s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [6.276s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [6.278s] [ext: omni.usd.schema.anim-0.0.0] startup
# [6.295s] [ext: usdrt.scenegraph-7.6.1] startup
# [6.326s] [ext: omni.activity.core-1.0.3] startup
# [6.327s] [ext: omni.kit.actions.core-1.0.0] startup
# [6.329s] [ext: omni.usd_resolver-1.0.0] startup
# [6.332s] [ext: omni.kit.commands-1.4.10] startup
# [6.335s] [ext: omni.usd.core-1.5.3] startup
# [6.337s] [ext: omni.resourcemonitor-107.0.1] startup
# [6.338s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [6.339s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [6.345s] [ext: omni.kit.usd_undo-0.1.8] startup
# [6.346s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [6.349s] [ext: omni.graph.exec-0.9.6] startup
# [6.350s] [ext: omni.timeline-1.0.14] startup
# [6.352s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [6.354s] [ext: omni.kit.exec.core-0.13.4] startup
# [6.355s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [6.359s] [ext: omni.usd-1.13.10] startup
# 2025-09-10T07:38:22Z [6,367ms] [Warning] [omni.usd.audio] failed to subscribe to stage events
# [6.394s] [ext: omni.kit.asset_converter-5.0.12] startup
# [6.404s] [ext: isaacsim.robot.schema-3.5.1] startup
# [6.414s] [ext: omni.anim.navigation.schema-107.3.0] startup
# [6.418s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [6.423s] [ext: omni.inspect-1.0.2] startup
# [6.425s] [ext: omni.kit.notification_manager-1.0.10] startup
# [6.426s] [ext: omni.graph.core-2.184.3] startup
# [6.428s] [ext: isaacsim.core.deprecation_manager-0.2.7] startup
# [6.429s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [6.430s] [ext: omni.pip.cloud-1.3.6] startup
# [6.432s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [6.435s] [ext: omni.anim.graph.schema-107.3.0] startup
# [6.440s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [6.441s] [ext: omni.usd.schema.physx-107.3.18] startup
# [6.469s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [6.469s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [6.470s] [ext: omni.usd.schema.flow-107.1.1] startup
# [6.470s] [ext: omni.index.libs-380600.5717.0] startup
# [6.470s] [ext: omni.index-1.0.1] startup
# [6.471s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [6.471s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [6.473s] [ext: omni.kit.widget.nucleus_info-2.0.2] startup
# [6.473s] [ext: omni.kit.menu.core-1.1.2] startup
# [6.474s] [ext: omni.kit.widget.filebrowser-2.12.2] startup
# [6.477s] [ext: omni.kit.search_core-1.0.8] startup
# [6.478s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [6.480s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [6.481s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [6.482s] [ext: omni.kit.widget.search_delegate-1.0.7] startup
# [6.483s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [6.483s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [6.484s] [ext: omni.ui.scene-1.11.4] startup
# [6.521s] [ext: omni.kit.widget.versioning-1.4.10] startup
# [6.523s] [ext: omni.kit.clipboard-1.0.5] startup
# [6.524s] [ext: omni.kit.collaboration.telemetry-1.1.0] startup
# [6.560s] [ext: omni.kit.window.filepicker-2.13.3] startup
# [6.568s] [ext: omni.kit.collaboration.channel_manager-1.0.14] startup
# [6.569s] [ext: omni.volume-0.5.2] startup
# [6.571s] [ext: omni.ujitso.client-0.0.0] startup
# [6.571s] [ext: omni.kit.usd.layers-2.2.10] startup
# [6.579s] [ext: omni.hydra.rtx-1.0.0] startup
# 2025-09-10T07:38:23Z [6,576ms] [Warning] [omni.log] Source: omni.hydra was already registered.
# [6.606s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [6.609s] [ext: omni.kit.menu.utils-2.0.3] startup
# [6.616s] [ext: omni.kit.context_menu-1.8.6] startup
# [6.617s] [ext: omni.kit.raycast.query-1.1.0] startup
# [6.622s] [ext: omni.kit.material.library-2.0.7] startup
# [6.626s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [6.628s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [6.632s] [ext: omni.kit.hydra_texture-1.4.5] startup
# [6.635s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [6.636s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [6.636s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [6.640s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [6.641s] [ext: omni.kit.viewport.legacy_gizmos-1.0.18] startup
# [6.643s] [ext: omni.kit.widget.settings-1.2.3] startup
# [6.645s] [ext: omni.kit.viewport.window-107.0.12] startup
# [6.657s] [ext: omni.kit.window.preferences-1.8.0] startup
# [6.662s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [6.663s] [ext: omni.kit.widget.filter-1.1.4] startup
# [6.663s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [6.664s] [ext: omni.kit.manipulator.transform-107.0.0] startup
# [6.668s] [ext: omni.graph.tools-1.79.2] startup
# [6.686s] [ext: omni.kit.widget.text_editor-1.1.1] startup
# [6.688s] [ext: omni.graph-1.141.2] startup
# [6.725s] [ext: omni.kit.window.extensions-1.4.26] startup
# [6.731s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [6.733s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [6.734s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [6.736s] [ext: omni.kit.widget.live_session_management.ui-1.0.3] startup
# [6.738s] [ext: omni.kit.collaboration.presence_layer-1.1.2] startup
# [6.741s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [6.742s] [ext: omni.kit.widget.stage-3.1.4] startup
# [6.751s] [ext: omni.kit.widget.live_session_management-1.2.23] startup
# [6.754s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [6.755s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [6.756s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [6.757s] [ext: omni.kit.window.file-2.0.5] startup
# [6.760s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [6.761s] [ext: omni.kit.window.property-1.12.1] startup
# [6.764s] [ext: omni.kit.window.content_browser-3.1.1] startup
# [6.774s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [6.776s] [ext: omni.kit.widget.toolbar-2.0.1] startup
# [6.782s] [ext: omni.kit.property.usd-4.5.11] startup
# [6.793s] [ext: omni.kit.manipulator.tool.snap-1.5.13] startup
# [6.797s] [ext: omni.kit.manipulator.selector-1.1.3] startup
# [6.799s] [ext: isaacsim.core.version-2.0.6] startup
# [6.799s] [ext: omni.ui_query-1.1.8] startup
# [6.801s] [ext: isaacsim.storage.native-1.2.8] startup
# [6.802s] [ext: omni.graph.ui-1.101.7] startup
# [6.820s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [6.824s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [6.826s] [ext: omni.graph.scriptnode-1.50.0] startup
# [6.827s] [ext: omni.kvdb-107.3.18] startup
# [6.830s] [ext: omni.kit.manipulator.prim.core-107.0.8] startup
# [6.845s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [6.848s] [ext: omni.physx.foundation-107.3.18] startup
# [6.850s] [ext: omni.localcache-107.3.18] startup
# [6.852s] [ext: omni.convexdecomposition-107.3.18] startup
# [6.854s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [6.855s] [ext: omni.fabric.commands-1.1.6] startup
# [6.858s] [ext: omni.usdphysics-107.3.18] startup
# [6.860s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [6.862s] [ext: omni.physx.cooking-107.3.18] startup
# [6.865s] [ext: omni.physics-107.3.18] startup
# [6.868s] [ext: omni.kit.window.cursor-1.1.4] startup
# [6.869s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [6.869s] [ext: omni.debugdraw-0.1.4] startup
# [6.873s] [ext: omni.physx-107.3.18] startup
# [6.882s] [ext: omni.physics.stageupdate-107.3.18] startup
# [6.885s] [ext: omni.kit.viewport.menubar.core-107.1.5] startup
# [6.943s] [ext: omni.kit.viewport.actions-107.0.2] startup
# [6.947s] [ext: omni.kit.widget.layers-1.8.6] startup
# [6.957s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [6.960s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [6.962s] [ext: omni.kit.widget.graph-2.0.0] startup
# [6.966s] [ext: omni.usdphysics.ui-107.3.18] startup
# [6.989s] [ext: omni.physx.commands-107.3.18] startup
# [6.995s] [ext: omni.physics.tensors-107.3.18] startup
# [7.000s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [7.001s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# [7.004s] [ext: omni.physx.ui-107.3.18] startup
# [7.028s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [7.030s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [7.033s] [ext: omni.warp.core-1.8.1] startup
# [7.261s] [ext: omni.usd.metrics.assembler.physics-107.3.18] startup
# [7.265s] [ext: omni.physics.physx-107.3.18] startup
# [7.267s] [ext: omni.kit.numpy.common-0.1.2] startup
# [7.269s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [7.271s] [ext: omni.isaac.dynamic_control-2.0.7] startup
# 2025-09-10T07:38:23Z [7,258ms] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# [7.275s] [ext: omni.kit.window.material_graph-1.8.23] startup
# [7.301s] [ext: omni.graph.image.core-0.6.1] startup
# [7.303s] [ext: isaacsim.core.utils-3.4.5] startup
# [7.306s] [ext: omni.kit.stage_templates-2.0.0] startup
# [7.309s] [ext: omni.graph.action_core-1.1.7] startup
# [7.310s] [ext: omni.kit.widget.stage_icons-1.0.8] startup
# [7.312s] [ext: omni.physx.tensors-107.3.18] startup
# [7.315s] [ext: isaacsim.test.docstring-1.1.0] startup
# [7.318s] [ext: isaacsim.core.simulation_manager-1.3.2] startup
# [8.713s] [ext: isaacsim.core.experimental.utils-0.2.0] startup
# [8.716s] [ext: omni.graph.action_nodes_core-1.2.0] startup
# [8.718s] [ext: omni.kit.window.stage-2.6.1] startup
# [8.723s] [ext: isaacsim.core.experimental.prims-0.6.2] startup
# [8.747s] [ext: omni.graph.action_nodes-1.51.0] startup
# [8.750s] [ext: omni.kit.menu.stage-1.2.7] startup
# [8.752s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [8.774s] [ext: omni.graph.action-1.130.0] startup
# [8.776s] [ext: omni.kit.widget.zoombar-1.0.7] startup
# [8.779s] [ext: omni.kit.usd.collect-2.4.5] startup
# [8.782s] [ext: omni.kit.browser.core-2.3.16] startup
# [8.790s] [ext: omni.kit.tool.collect-2.2.18] startup
# [8.793s] [ext: omni.kit.browser.folder.core-1.10.10] startup
# [8.797s] [ext: omni.kit.usdz_export-1.0.9] startup
# [8.799s] [ext: omni.kit.ui_test-1.3.6] startup
# [8.801s] [ext: omni.kit.tool.asset_importer-4.3.2] startup
# [8.806s] [ext: isaacsim.gui.components-1.1.9] startup
# [8.810s] [ext: isaacsim.examples.browser-0.1.12] startup
# [8.815s] [ext: isaacsim.asset.importer.urdf-2.4.19] startup
# [8.867s] [ext: isaacsim.core.prims-0.5.1] startup
# [8.889s] [ext: omni.graph.image.nodes-1.3.1] startup
# [8.891s] [ext: isaacsim.core.experimental.materials-0.3.0] startup
# [8.893s] [ext: omni.graph.nodes_core-1.1.0] startup
# [8.898s] [ext: isaacsim.core.api-4.6.10] startup
# [8.906s] [ext: omni.kit.selection-0.1.6] startup
# [8.910s] [ext: omni.graph.nodes-1.171.0] startup
# [8.917s] [ext: omni.kit.widget.imageview-1.0.4] startup
# [8.918s] [ext: isaacsim.robot.surface_gripper-3.2.6] startup
# [8.921s] [ext: isaacsim.gui.menu-2.3.17] startup
# [14.133s] [ext: omni.graph.ui_nodes-1.50.8] startup
# [14.137s] [ext: omni.videoencoding-0.1.2] startup
# [14.141s] [ext: omni.syntheticdata-0.6.13] startup
# [14.155s] [ext: isaacsim.robot.surface_gripper.ui-3.0.2] startup
# [14.159s] [ext: omni.warp-1.8.1] startup
# [14.168s] [ext: omni.kit.window.quicksearch-2.4.4] startup
# [14.184s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [14.188s] [ext: omni.kit.graph.delegate.modern-1.10.8] startup
# [14.192s] [ext: omni.replicator.core-1.12.17] startup
# 2025-09-10T07:38:30Z [14,196ms] [Warning] [pxr.Semantics] pxr.Semantics is deprecated - please use Semantics instead
# Warp 1.8.1 initialized:
#    CUDA Toolkit 12.8, Driver 12.2
#    Devices:
#      "cpu"      : "CPU"
#      "cuda:0"   : "NVIDIA GeForce RTX 3060" (12 GiB, sm_86, mempool enabled)
#    Kernel cache:
#      /home/sysadmin/.cache/warp/1.8.1
# 2025-09-10T07:38:30Z [14,331ms] [Warning] [omni.replicator.core.scripts.extension] No material configuration file, adding configuration to material settings directly.
# [14.351s] [ext: omni.graph.window.core-2.0.0] startup
# [14.369s] [ext: isaacsim.core.nodes-3.2.16] startup
# [14.377s] [ext: omni.graph.window.generic-1.50.2] startup
# [14.388s] [ext: isaacsim.sensors.camera-1.3.1] startup
# [14.398s] [ext: isaacsim.core.throttling-2.1.10] startup
# [14.404s] [ext: isaacsim.sensors.camera.ui-0.2.0] startup
# [14.408s] [ext: isaacsim.sensors.physics-0.3.27] startup
# [14.415s] [ext: omni.anim.navigation.core-107.3.0] startup
# [14.429s] [ext: isaacsim.robot.policy.examples-4.1.11] startup
# [14.436s] [ext: omni.anim.navigation.meshtools-107.3.0] startup
# [14.559s] [ext: omni.isaac.quadruped-3.0.7] startup
# 2025-09-10T07:38:31Z [14,544ms] [Warning] [omni.isaac.quadruped] omni.isaac.quadruped has been deprecated in favor of isaacsim.robot.policy.examples. Please update your code accordingly.
# [14.561s] [ext: isaacsim.robot_motion.lula-4.0.8] startup
# [14.574s] [ext: isaacsim.asset.browser-1.3.19] startup
# [14.580s] [ext: isaacsim.robot.manipulators-3.3.5] startup
# [14.586s] [ext: isaacsim.robot_motion.motion_generation-8.0.25] startup
# [14.616s] [ext: omni.isaac.asset_browser-1.0.6] startup
# 2025-09-10T07:38:31Z [14,601ms] [Warning] [omni.isaac.asset_browser] omni.isaac.asset_browser has been deprecated in favor of isaacsim.asset.browser. Please update your code accordingly.
# [14.619s] [ext: isaacsim.core.cloner-1.4.9] startup
# [14.625s] [ext: isaacsim.robot.manipulators.examples-1.0.17] startup
# [14.629s] [ext: omni.isaac.assets_check-0.3.13] startup
# 2025-09-10T07:38:31Z [14,613ms] [Warning] [omni.isaac.assets_check] omni.isaac.assets_check has been deprecated in favor of isaacsim.asset.browser. Please update your code accordingly.
# [14.631s] [ext: omni.isaac.cloner-1.0.7] startup
# 2025-09-10T07:38:31Z [14,616ms] [Warning] [omni.isaac.cloner] omni.isaac.cloner has been deprecated in favor of isaacsim.core.cloner. Please update your code accordingly.
# [14.634s] [ext: isaacsim.cortex.framework-1.0.12] startup
# [14.638s] [ext: omni.isaac.core-4.0.7] startup
# 2025-09-10T07:38:31Z [14,623ms] [Warning] [omni.isaac.core.physics_context.physics_context] omni.isaac.core.physics_context.physics_context has been deprecated in favor of isaacsim.core.api.physics_context.physics_context. Please update your code accordingly.
# 2025-09-10T07:38:31Z [14,623ms] [Warning] [omni.isaac.core.simulation_context.simulation_context] omni.isaac.core.simulation_context.simulation_context has been deprecated in favor of isaacsim.core.api.simulation_context.simulation_context. Please update your code accordingly.
# 2025-09-10T07:38:31Z [14,624ms] [Warning] [omni.isaac.core.world.world] omni.isaac.core.world.world has been deprecated in favor of isaacsim.core.api.world.world. Please update your code accordingly.
# 2025-09-10T07:38:31Z [14,624ms] [Warning] [omni.isaac.core] omni.isaac.core has been deprecated in favor of isaacsim.core.api. Please update your code accordingly.
# [14.641s] [ext: isaacsim.core.experimental.objects-0.2.4] startup
# [14.651s] [ext: isaacsim.cortex.behaviors-2.0.12] startup
# [14.654s] [ext: omni.isaac.cortex-1.0.5] startup
# 2025-09-10T07:38:31Z [14,639ms] [Warning] [omni.isaac.cortex] omni.isaac.cortex has been deprecated in favor of isaacsim.cortex.framework. Please update your code accordingly.
# [14.656s] [ext: isaacsim.simulation_app-2.9.2] startup
# [14.658s] [ext: omni.isaac.cortex.sample_behaviors-2.0.5] startup
# 2025-09-10T07:38:31Z [14,642ms] [Warning] [omni.isaac.cortex.sample_behaviors] omni.isaac.cortex.sample_behaviors has been deprecated in favor of isaacsim.cortex.behaviors. Please update your code accordingly.
# [14.660s] [ext: omni.kit.viewport.menubar.render-107.0.9] startup
# [14.668s] [ext: omni.isaac.kit-2.0.6] startup
# 2025-09-10T07:38:31Z [14,652ms] [Warning] [omni.isaac.kit] omni.isaac.kit has been deprecated in favor of isaacsim.simulation_app. Please update your code accordingly.
# [14.670s] [ext: omni.sensors.nv.common-2.7.0-coreapi] startup
# [14.689s] [ext: omni.isaac.franka-1.0.7] startup
# 2025-09-10T07:38:31Z [14,689ms] [Warning] [omni.isaac.franka] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.franka. Please update your code accordingly.
# 2025-09-10T07:38:31Z [14,689ms] [Warning] [omni.isaac.franka.franka] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.franka. Please update your code accordingly.
# 2025-09-10T07:38:31Z [14,694ms] [Warning] [omni.isaac.franka.kinematics_solver] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.franka. Please update your code accordingly.
# [14.712s] [ext: omni.isaac.lula-4.0.6] startup
# 2025-09-10T07:38:31Z [14,699ms] [Warning] [omni.isaac.lula] omni.isaac.lula has been deprecated in favor of isaacsim.robot_motion.lula. Please update your code accordingly.
# [14.719s] [ext: isaacsim.robot_motion.lula_test_widget-1.0.12] startup
# [14.738s] [ext: omni.sensors.nv.materials-1.6.0-coreapi] startup
# [14.747s] [ext: omni.sensors.nv.wpm-2.5.0-coreapi] startup
# [14.752s] [ext: omni.sensors.net-0.4.0-coreapi] startup
# [14.786s] [ext: omni.isaac.lula_test_widget-1.0.6] startup
# 2025-09-10T07:38:31Z [14,772ms] [Warning] [omni.isaac.lula_test_widget] omni.isaac.lula_test_widget has been deprecated in favor of isaacsim.robot_motion.lula_test_widget. Please update your code accordingly.
# [14.790s] [ext: isaacsim.util.debug_draw-3.1.0] startup
# [14.806s] [ext: omni.sensors.nv.radar-2.8.0-coreapi] startup
# [14.814s] [ext: omni.sensors.nv.lidar-2.7.0-coreapi] startup
# [14.826s] [ext: omni.sensors.nv.ids-1.5.0-coreapi] startup
# [14.839s] [ext: isaacsim.gui.sensors.icon-2.0.3] startup
# [14.922s] [ext: isaacsim.sensors.physx-2.2.27] startup
# [14.938s] [ext: isaacsim.sensors.rtx-15.5.0] startup
# [15.014s] [ext: isaacsim.gui.content_browser-0.1.9] startup
# Warp DeprecationWarning: The `warp.sim` module is deprecated and will be removed in v1.10. Please transition to using the forthcoming Newton library instead.
# [15.096s] [ext: omni.isaac.range_sensor-4.0.6] startup
# 2025-09-10T07:38:31Z [15,217ms] [Warning] [omni.isaac.range_sensor] omni.isaac.range_sensor has been deprecated in favor of isaacsim.sensors.physx. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,220ms] [Warning] [omni.isaac.range_sensor.commands] omni.isaac.range_sensor.commands has been deprecated in favor of isaacsim.sensors.physx.commands. Please update your code accordingly.
# [15.237s] [ext: omni.isaac.sensor-13.0.7] startup
# 2025-09-10T07:38:31Z [15,223ms] [Warning] [omni.isaac.sensor] omni.isaac.sensor has been deprecated in favor of isaacsim.sensors.camera, isaacsim.sensors.physics, isaacsim.sensors.physx, and isaacsim.sensors.rtx. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,223ms] [Warning] [omni.isaac.sensor.camera] omni.isaac.sensor.camera has been deprecated in favor of isaacsim.sensors.camera.camera. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,223ms] [Warning] [omni.isaac.sensor.camera_view] omni.isaac.sensor.camera_view has been deprecated in favor of isaacsim.sensors.camera.camera_view. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,225ms] [Warning] [omni.isaac.sensor.commands] omni.isaac.sensor.commands has been deprecated in favor of isaacsim.sensors.physics.commands, isaacsim.sensors.physx.commands, and isaacsim.sensors.rtx.commands. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,225ms] [Warning] [omni.isaac.sensor.contact_sensor] omni.isaac.sensor.contact_sensor has been deprecated in favor of isaacsim.sensors.physics.contact_sensor. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,225ms] [Warning] [omni.isaac.sensor.imu_sensor] omni.isaac.sensor.imu_sensor has been deprecated in favor of isaacsim.sensors.physics.imu_sensor. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,226ms] [Warning] [omni.isaac.sensor.lidar_rtx] omni.isaac.sensor.lidar_rtx has been deprecated in favor of isaacsim.sensors.rtx.lidar_rtx. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,226ms] [Warning] [omni.isaac.sensor.rotating_lidar_physX] omni.isaac.sensor.imu_sensor has been deprecated in favor of isaacsim.sensors.physix.rotating_lidar_physX. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,226ms] [Warning] [omni.isaac.sensor.scripts.samples.contact_sensor] omni.isaac.sensor.scripts.samples.contact_sensor has been deprecated in favor of isaacsim.sensors.physics.scripts.samples.contact_sensor. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,227ms] [Warning] [omni.isaac.sensor.scripts.samples.imu_sensor] omni.isaac.sensor.scripts.samples.imu_sensor has been deprecated in favor of isaacsim.sensors.physics.scripts.samples.imu_sensor. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,227ms] [Warning] [omni.isaac.sensor.scripts.samples.lightbeam_sensor] omni.isaac.sensor.scripts.samples.lightbeam_sensor has been deprecated in favor of isaacsim.sensors.physx.scripts.samples.lightbeam_sensor. Please update your code accordingly.
# [15.244s] [ext: isaacsim.robot.wheeled_robots-4.0.23] startup
# [15.262s] [ext: omni.isaac.surface_gripper-2.0.6] startup
# 2025-09-10T07:38:31Z [15,247ms] [Warning] [omni.isaac.surface_gripper] omni.isaac.surface_gripper has been deprecated in favor of isaacsim.robot.surface_gripper. Please update your code accordingly.
# [15.265s] [ext: omni.isaac.universal_robots-1.0.6] startup
# 2025-09-10T07:38:31Z [15,249ms] [Warning] [omni.isaac.universal_robots] omni.isaac.universal_robots has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,250ms] [Warning] [omni.isaac.universal_robots.kinematics_solver] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,254ms] [Warning] [omni.isaac.universal_robots.ur10] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# [15.272s] [ext: omni.isaac.utils-2.0.6] startup
# [15.279s] [ext: omni.isaac.version-2.0.7] startup
# 2025-09-10T07:38:31Z [15,263ms] [Warning] [omni.isaac.version] omni.isaac.version has been deprecated in favor of isaacsim.core.version. Please update your code accordingly.
# [15.287s] [ext: omni.isaac.wheeled_robots-3.0.7] startup
# 2025-09-10T07:38:31Z [15,272ms] [Warning] [omni.isaac.wheeled_robots] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,273ms] [Warning] [omni.isaac.wheeled_robots.controllers] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,273ms] [Warning] [omni.isaac.wheeled_robots.controllers.ackermann_controller] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,275ms] [Warning] [omni.isaac.wheeled_robots.controllers.differential_controller] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,275ms] [Warning] [omni.isaac.wheeled_robots.controllers.holonomic_controller] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,276ms] [Warning] [omni.isaac.wheeled_robots.controllers.quintic_path_planner] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,276ms] [Warning] [omni.isaac.wheeled_robots.controllers.stanley_control] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,277ms] [Warning] [omni.isaac.wheeled_robots.controllers.wheel_base_pose_controller] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,277ms] [Warning] [omni.isaac.wheeled_robots.impl] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,278ms] [Warning] [omni.isaac.wheeled_robots.robots] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,278ms] [Warning] [omni.isaac.wheeled_robots.robots.holonomic_robot_usd_setup] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,282ms] [Warning] [omni.isaac.wheeled_robots.robots.wheeled_robot] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# [15.304s] [ext: omni.kit.menu.create-2.0.1] startup
# [15.307s] [ext: omni.kit.property.audio-1.0.16] startup
# [15.316s] [ext: omni.kit.property.camera-1.0.10] startup
# [15.320s] [ext: omni.kit.property.geometry-2.0.4] startup
# [15.326s] [ext: omni.hydra.scene_api-0.1.2] startup
# [15.334s] [ext: omni.kit.property.light-1.0.12] startup
# [15.349s] [ext: isaacsim.app.about-2.0.11] startup
# [15.351s] [ext: omni.kit.property.material-1.11.9] startup
# [15.356s] [ext: omni.kit.property.render-1.2.1] startup
# [15.358s] [ext: omni.kit.property.transform-1.5.12] startup
# [15.361s] [ext: isaacsim.gui.property-1.1.3] startup
# [15.364s] [ext: omni.isaac.window.about-2.0.7] startup
# 2025-09-10T07:38:31Z [15,348ms] [Warning] [omni.isaac.window.about] omni.isaac.window.about has been deprecated in favor of isaacsim.app.about. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,348ms] [Warning] [omni.isaac.window.about.about] omni.isaac.window.about.about has been deprecated in favor of isaacsim.app.about.about. Please update your code accordingly.
# [15.365s] [ext: omni.kit.manipulator.camera-106.0.4] startup
# [15.369s] [ext: omni.isaac.core_nodes-2.0.6] startup
# 2025-09-10T07:38:31Z [15,352ms] [Warning] [omni.isaac.core_nodes] omni.isaac.core_nodes has been deprecated in favor of isaacsim.core.nodes. Please update your code accordingly.
# [15.370s] [ext: omni.kit.property.bundle-1.4.1] startup
# [15.374s] [ext: omni.kit.property.isaac-1.0.6] startup
# 2025-09-10T07:38:31Z [15,358ms] [Warning] [omni.kit.property.isaac] omni.kit.property.isaac has been deprecated in favor of isaacsim.gui.property. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,358ms] [Warning] [omni.kit.property.isaac.widgets] omni.kit.property.isaac.widgets has been deprecated in favor of isaacsim.gui.property.widgets. Please update your code accordingly.
# [15.375s] [ext: omni.kit.scripting-107.3.1] startup
# [15.381s] [ext: omni.isaac.manipulators-3.0.7] startup
# 2025-09-10T07:38:31Z [15,364ms] [Warning] [omni.isaac.manipulators] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,364ms] [Warning] [omni.isaac.manipulators.controllers] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,364ms] [Warning] [omni.isaac.manipulators.controllers.pick_place_controller] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,365ms] [Warning] [omni.isaac.manipulators.controllers.stacking_controller] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,365ms] [Warning] [omni.isaac.manipulators.grippers] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,365ms] [Warning] [omni.isaac.manipulators.grippers.gripper] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,365ms] [Warning] [omni.isaac.manipulators.grippers.parallel_gripper] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,365ms] [Warning] [omni.isaac.manipulators.grippers.surface_gripper] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,365ms] [Warning] [omni.isaac.manipulators.manipulators] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,365ms] [Warning] [omni.isaac.manipulators.manipulators.single_manipulator] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# [15.382s] [ext: omni.kit.viewport.menubar.camera-107.0.3] startup
# [15.391s] [ext: omni.kit.viewport.menubar.lighting-107.3.1] startup
# [15.393s] [ext: isaacsim.replicator.writers-1.0.15] startup
# [15.405s] [ext: omni.isaac.menu-1.0.6] startup
# 2025-09-10T07:38:31Z [15,390ms] [Warning] [omni.isaac.menu] omni.isaac.menu has been deprecated in favor of isaacsim.gui.menu. Please update your code accordingly.
# [15.408s] [ext: isaacsim.replicator.behavior-1.1.14] startup
# [15.410s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [15.420s] [ext: omni.kit.window.console-1.1.4] startup
# [15.426s] [ext: isaacsim.replicator.domain_randomization-1.0.16] startup
# [15.428s] [ext: isaacsim.replicator.examples-1.1.31] startup
# [15.430s] [ext: omni.ocio-0.1.1] startup
# [15.433s] [ext: omni.rtx.window.settings-0.6.19] startup
# [15.443s] [ext: omni.kit.window.status_bar-0.1.8] startup
# [15.456s] [ext: omni.kit.window.toolbar-2.0.0] startup
# [15.459s] [ext: omni.replicator.isaac-2.0.8] startup
# 2025-09-10T07:38:31Z [15,443ms] [Warning] [omni.replicator.isaac] omni.replicator.isaac has been deprecated in favor of isaacsim.replicator.domain_randomization, isaacsim.replicator.examples, isaacsim.replicator.writers. Please update your code accordingly.
# [15.460s] [ext: omni.replicator.replicator_yaml-2.0.11] startup
# [15.475s] [ext: omni.rtx.settings.core-0.6.5] startup
# [15.480s] [ext: omni.usd.metrics.assembler.ui-107.3.1] startup
# [15.492s] [ext: omni.isaac.motion_generation-8.0.7] startup
# 2025-09-10T07:38:31Z [15,476ms] [Warning] [omni.isaac.motion_generation] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,476ms] [Warning] [omni.isaac.motion_generation.articulation_kinematics_solver] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,476ms] [Warning] [omni.isaac.motion_generation.articulation_motion_policy] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,476ms] [Warning] [omni.isaac.motion_generation.articulation_trajectory] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,476ms] [Warning] [omni.isaac.motion_generation.kinematics_interface] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,476ms] [Warning] [omni.isaac.motion_generation.lula] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.lula.kinematics] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.lula.motion_policies] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.lula.path_planners] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.lula.trajectory_generator] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.motion_policy_controller] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.motion_policy_interface] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.path_planner_visualizer] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.path_planning_interface] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.trajectory] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T07:38:31Z [15,477ms] [Warning] [omni.isaac.motion_generation.world_interface] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# [15.495s] [ext: semantics.schema.editor-2.0.1] startup
# [15.500s] [ext: isaacsim.examples.extension-2.0.12] startup
# [15.501s] [ext: omni.kit.ui.actions-1.0.5] startup
# [15.505s] [ext: semantics.schema.property-2.0.1] startup
# [15.507s] [ext: omni.isaac.nucleus-1.0.6] startup
# 2025-09-10T07:38:32Z [15,490ms] [Warning] [omni.isaac.nucleus] omni.isaac.nucleus has been deprecated in favor of isaacsim.storage.native. Please update your code accordingly.
# 2025-09-10T07:38:32Z [15,490ms] [Warning] [omni.isaac.nucleus.nucleus] omni.isaac.nucleus.nucleus has been deprecated in favor of isaacsim.storage.native. Please update your code accordingly.
# [15.508s] [ext: omni.anim.curve.core-1.3.1] startup
# [15.518s] [ext: isaacsim.asset.importer.mjcf-2.5.8] startup
# [15.523s] [ext: isaacsim.examples.interactive-4.6.10] startup
# [15.540s] [ext: omni.kit.menu.common-2.0.0] startup
# [15.551s] [ext: isaacsim.exp.base-5.0.0] startup
# [15.554s] [ext: omni.kit.stage.copypaste-1.2.4] startup
# [15.568s] [ext: isaacsim.sensors.physics.ui-0.1.12] startup
# [15.577s] [ext: isaacsim.sensors.physics.examples-0.1.15] startup
# [15.579s] [ext: isaacsim.replicator.behavior.ui-1.0.5] startup
# [15.585s] [ext: omni.anim.curve.ui-1.4.1] startup
# [15.590s] [ext: isaacsim.robot.manipulators.ui-2.1.22] startup
# [15.592s] [ext: isaacsim.util.physics-1.1.5] startup
# [15.598s] [ext: omni.anim.curve.bundle-1.2.3] startup
# [15.599s] [ext: omni.kit.browser.asset-1.3.12] startup
# [15.601s] [ext: omni.anim.shared.core-107.0.1] startup
# [15.606s] [ext: isaacsim.robot.wheeled_robots.ui-2.1.23] startup
# [15.609s] [ext: isaacsim.asset.importer.heightmap-2.0.6] startup
# [15.613s] [ext: omni.graph.window.action-1.50.2] startup
# [15.621s] [ext: omni.simready.explorer-1.1.3] startup
# [15.633s] [ext: omni.importer.onshape-1.0.0] startup
# [15.646s] [ext: isaacsim.robot_setup.gain_tuner-3.0.5] startup
# [15.656s] [ext: omni.isaac.block_world-2.0.6] startup
# 2025-09-10T07:38:32Z [15,641ms] [Warning] [omni.isaac.block_world] ['omni.isaac.block_world'] has been deprecated in favor of ['isaacsim.asset.importer.heightmap']. Please update your code accordingly.
# [15.659s] [ext: isaacsim.asset.gen.omap-2.0.28] startup
# [15.665s] [ext: isaacsim.robot_setup.grasp_editor-2.0.18] startup
# [15.672s] [ext: omni.isaac.extension_templates-2.0.7] startup
# 2025-09-10T07:38:32Z [15,655ms] [Warning] [omni.isaac.extension_templates] omni.isaac.extension_templates has been deprecated in favor of isaacsim.examples.extension. Please update your code accordingly.
# [15.674s] [ext: omni.isaac.gain_tuner-2.0.5] startup
# [15.676s] [ext: isaacsim.sensors.physx.examples-2.2.15] startup
# [15.678s] [ext: omni.isaac.occupancy_map-2.0.8] startup
# 2025-09-10T07:38:32Z [15,662ms] [Warning] [omni.isaac.occupancy_map] omni.isaac.occupancy_map has been deprecated in favor of isaacsim.asset.gen.omap. Please update your code accordingly.
# [15.684s] [ext: omni.isaac.grasp_editor-2.0.7] startup
# 2025-09-10T07:38:32Z [15,668ms] [Warning] [omni.isaac.grasp_editor] omni.isaac.grasp_editor has been deprecated in favor of isaacsim.robot_setup.grasp_editor. Please update your code accordingly.
# [15.685s] [ext: isaacsim.sensors.rtx.ui-1.1.4] startup
# [15.689s] [ext: isaacsim.robot_setup.assembler-3.0.8] startup
# [15.694s] [ext: isaacsim.robot_setup.xrdf_editor-3.1.11] startup
# [15.698s] [ext: omni.isaac.range_sensor.examples-2.0.6] startup
# 2025-09-10T07:38:32Z [15,683ms] [Warning] [omni.isaac.range_sensor.examples] omni.isaac.range_sensor.examples has been deprecated in favor of isaacsim.sensors.physx.examples. Please update your code accordingly.
# 2025-09-10T07:38:32Z [15,683ms] [Warning] [omni.isaac.range_sensor.examples.lidar_info] omni.isaac.range_sensor.examples.lidar_info has been deprecated in favor of isaacsim.sensors.physx.examples.lidar_info. Please update your code accordingly.
# 2025-09-10T07:38:32Z [15,683ms] [Warning] [omni.isaac.range_sensor.examples.generic_info] omni.isaac.range_sensor.examples.generic_info has been deprecated in favor of isaacsim.sensors.physx.examples.generic_info. Please update your code accordingly.
# [15.701s] [ext: isaacsim.util.merge_mesh-2.0.15] startup
# [15.707s] [ext: isaacsim.replicator.scene_blox-1.0.8] startup
# 2025-09-10T07:38:32Z [15,692ms] [Warning] [isaacsim.replicator.scene_blox] isacsim.replicator.scene_blox has been deprecated since Isaac Sim 5.0.0.
# [15.711s] [ext: isaacsim.replicator.synthetic_recorder-2.2.15] startup
# [15.715s] [ext: omni.isaac.robot_assembler-2.0.8] startup
# 2025-09-10T07:38:32Z [15,699ms] [Warning] [omni.isaac.robot_assembler] omni.isaac.robot_assembler has been deprecated in favor of isaacsim.robot_setup.assembler. Please update your code accordingly.
# [15.717s] [ext: omni.isaac.robot_description_editor-3.0.5] startup
# [15.717s] [ext: isaacsim.asset.gen.omap.ui-2.2.1] startup
# [15.720s] [ext: omni.kit.actions.window-1.1.3] startup
# [15.728s] [ext: omni.isaac.scene_blox-1.0.6] startup
# 2025-09-10T07:38:32Z [15,712ms] [Warning] [omni.isaac.scene_blox] omni.isaac.scene_blox has been deprecated in favor of isaacsim.replicator.scene_blox. Please update your code accordingly.
# [15.730s] [ext: omni.isaac.synthetic_recorder-2.0.6] startup
# 2025-09-10T07:38:32Z [15,714ms] [Warning] [omni.isaac.synthetic_recorder] omni.isaac.synthetic_recorder has been deprecated in favor of isaacsim.replicator.synthetic_recorder. Please update your code accordingly.
# [15.732s] [ext: omni.isaac.throttling-2.0.7] startup
# 2025-09-10T07:38:32Z [15,716ms] [Warning] [omni.isaac.throttling] omni.isaac.throttling has been deprecated in favor of isaacsim.core.throttling. Please update your code accordingly.
# 2025-09-10T07:38:32Z [15,717ms] [Warning] [omni.isaac.throttling.throttling] omni.isaac.throttling.throttling has been deprecated in favor of isaacsim.core.throttling.extension. Please update your code accordingly.
# [15.734s] [ext: omni.kit.core.collection-0.2.3] startup
# [15.737s] [ext: omni.isaac.occupancy_map.ui-2.0.8] startup
# 2025-09-10T07:38:32Z [15,720ms] [Warning] [omni.isaac.occupancy_map.ui] omni.isaac.occupancy_map.ui has been deprecated in favor of isaacsim.asset.gen.omap.ui. Please update your code accordingly.
# [15.738s] [ext: omni.kit.hotkeys.window-1.4.9] startup
# [15.748s] [ext: omni.kit.mesh.raycast-107.0.1] startup
# [15.752s] [ext: omni.kit.preferences.animation-1.2.0] startup
# [15.755s] [ext: omni.graph.bundle.action-2.30.0] startup
# [15.758s] [ext: omni.kit.property.collection-0.2.3] startup
# [15.761s] [ext: omni.mdl.usd_converter-1.0.30] startup
# [15.764s] [ext: omni.kit.property.layer-1.1.9] startup
# [15.768s] [ext: omni.kit.stagerecorder.core-107.0.3] startup
# [15.773s] [ext: omni.kit.search.files-1.0.4] startup
# [15.775s] [ext: omni.kit.browser.material-1.6.2] startup
# [15.778s] [ext: omni.kit.window.title-1.1.7] startup
# [15.780s] [ext: omni.kit.stage.mdl_converter-1.0.8] startup
# [15.782s] [ext: omni.kit.widgets.custom-1.0.13] startup
# [15.793s] [ext: omni.kit.stagerecorder.ui-107.0.1] startup
# [15.797s] [ext: omni.kit.tool.remove_unused.core-0.1.3] startup
# [15.799s] [ext: omni.kit.window.material-1.6.3] startup
# [15.806s] [ext: omni.kit.stage_column.payload-2.0.3] startup
# [15.809s] [ext: omni.kit.stage_column.variant-1.0.17] startup
# [15.813s] [ext: omni.kit.variant.editor-107.3.0] startup
# [15.828s] [ext: omni.kit.stagerecorder.bundle-105.0.2] startup
# [15.829s] [ext: omni.kit.tool.asset_exporter-4.0.4] startup
# [15.832s] [ext: omni.kit.tool.remove_unused.controller-0.1.4] startup
# [15.835s] [ext: omni.kit.usda_edit-1.1.18] startup
# [15.842s] [ext: omni.kit.widget.live-2.1.11] startup
# [15.845s] [ext: omni.kit.variant.presenter-107.0.0] startup
# [15.849s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [15.851s] [ext: omni.kit.widget.calendar-1.0.9] startup
# [15.853s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [15.853s] [ext: omni.kit.viewport_widgets_manager-1.0.9] startup
# [15.855s] [ext: omni.kit.widget.cache_indicator-3.0.6] startup
# 2025-09-10T07:38:32Z [15,838ms] [Warning] [omni.kit.pipapi.pipapi] extension omni.kit.widget.cache_indicator-3.0.6 has a [python.pipapi] entry, but use_online_index=true is not set. It doesn't do anything and can be removed.
# [15.922s] [ext: omni.kit.property.physx-107.3.18] startup
# [15.947s] [ext: omni.physx.demos-107.3.18] startup
# [15.981s] [ext: omni.kit.widget.extended_searchfield-1.0.31] startup
# [15.993s] [ext: omni.kit.widget.schema_api-1.0.3] startup
# [15.996s] [ext: omni.asset_validator.core-1.1.6] startup
# [16.061s] [ext: omni.scene.optimizer.core-107.3.9] startup
# [16.107s] [ext: omni.usdex.libs-1.2.2] startup
# [16.117s] [ext: omni.physx.vehicle-107.3.18] startup
# [16.459s] [ext: omni.kit.window.commands-0.2.9] startup
# [16.461s] [ext: omni.kit.widget.timeline-107.0.1] startup
# [16.464s] [ext: omni.kit.window.script_editor-2.0.1] startup
# [16.467s] [ext: omni.asset_validator.ui-1.1.6] startup
# [16.478s] [ext: omni.physx.asset_validator-107.3.18] startup
# [16.490s] [ext: omni.kit.converter.common-506.3.1] startup
# [16.492s] [ext: isaacsim.sensors.physx.ui-2.2.12] startup
# [16.494s] [ext: omni.physx.camera-107.3.18] startup
# [16.502s] [ext: omni.physx.cct-107.3.18] startup
# [16.512s] [ext: omni.physx.graph-107.3.18] startup
# [16.528s] [ext: omni.physx.supportui-107.3.18] startup
# [16.542s] [ext: omni.physx.telemetry-107.3.18] startup
# [16.544s] [ext: omni.kit.converter.dgn_core-509.0.1] startup
# [16.602s] [ext: omni.isaac.range_sensor.ui-2.0.5] startup
# 2025-09-10T07:38:33Z [16,586ms] [Warning] [omni.isaac.range_sensor.ui] omni.isaac.range_sensor.ui has been deprecated in favor of isaacsim.sensors.physx.ui. Please update your code accordingly.
# 2025-09-10T07:38:33Z [16,586ms] [Warning] [omni.isaac.range_sensor.ui.menu] omni.isaac.range_sensor.ui.menu has been deprecated in favor of isaacsim.sensors.physx.ui.menu. Please update your code accordingly.
# [16.604s] [ext: omni.kit.converter.hoops_core-508.0.2] startup
# [16.611s] [ext: omni.kit.converter.jt_core-507.0.1] startup
# [16.628s] [ext: omni.kit.window.usd_paths-1.0.8] startup
# [16.630s] [ext: omni.kit.widget.collection-0.3.1] startup
# [16.633s] [ext: omni.physx.bundle-107.3.18] startup
# [16.633s] [ext: omni.kit.converter.dgn-508.0.1] startup
# [16.635s] [ext: isaacsim.replicator.grasping-1.0.9] startup
# [17.121s] [ext: omni.kit.converter.hoops-508.0.1] startup
# [17.125s] [ext: omni.kit.converter.jt-507.0.1] startup
# [17.126s] [ext: omni.kit.quicklayout-1.0.8] startup
# [17.128s] [ext: omni.kit.window.collection-0.3.1] startup
# 2025-09-10T07:38:33Z [17,112ms] [Warning] [omni.kit.window.collection.collection_watch] Get collection from usdrt stage failed: Attach(): incompatible function arguments. The following argument types are supported:
#     1. (stageId: int) -> usdrt.Usd._Usd.Stage
#     2. (fabricId: usdrt.helpers._helpers.FabricId) -> usdrt.Usd._Usd.Stage
#
# Invoked with: -1
# [17.130s] [ext: omni.isaac.physics_inspector-0.1.11] startup
# 2025-09-10T07:38:33Z [17,113ms] [Warning] [omni.isaac.physics_inspector] omni.isaac.physics_inspector has been deprecated.Replaced by Physics Visualization tools
# [17.131s] [ext: isaacsim.util.camera_inspector-1.0.15] startup
# [17.132s] [ext: isaacsim.replicator.grasping.ui-1.0.8] startup
# [17.136s] [ext: isaacsim.asset.validation-1.0.3] startup
# [17.158s] [ext: omni.kit.converter.cad-203.2.1] startup
# [17.159s] [ext: omni.kit.window.stats-0.1.7] startup
# [17.160s] [ext: isaacsim.app.setup-1.4.10] startup
# [17.162s] Isaac Sim Full Version: 5.0.0-rc.45
# [17.162s] Writing Isaac Sim icon file
# [17.162s] [ext: omni.kit.profiler.window-2.3.5] startup
# [17.168s] [ext: isaacsim.exp.full-5.0.0] startup
# Checking to see if RMW can be loaded:
# failed to get symbol 'rmw_init_options_init' due to Environment variable 'AMENT_PREFIX_PATH' is not set or empty, at /workspace/humble_ws/src/rmw_implementation/src/functions.cpp:171, at /workspace/humble_ws/src/rcl/rcl/src/rcl/init_options.c:75
# RMW was not loaded

# %%
import os
import contextlib
import asyncio

import nest_asyncio


class Kernel:
    def __init__(self, argv: list[str] = []):

        nest_asyncio.apply()

        @contextlib.contextmanager
        def _undo_isaacsim_monkeypatching():
            """
            Undo the unnecessary monkey-patching 
            of builtin Python modules done by `omni.kit.app`.

            .. seealso::
                * :func:`_startup_kit_scripting` in 
                `site-packages/omni/kernel/py/omni/kit/app/_impl/__init__.py`
            """

            import logging

            logging_handlers_orig = list(logging.root.handlers)
            logging_level_orig = int(logging.root.level)

            yield

            logging.root.handlers = logging_handlers_orig
            logging.root.level = logging_level_orig

        with _undo_isaacsim_monkeypatching():
            import isaacsim
            isaacsim.bootstrap_kernel()
            from isaacsim.simulation_app import AppFramework

            # TODO
            experience = ""
            if experience == "":
                # TODO use proper os.path.join
                for exp in [
                    "isaacsim.exp.full.kit",
                    "omni.isaac.sim.python.kit",
                    "isaacsim.exp.base.python.kit",
                    "isaacsim.exp.base.kit",
                ]:
                    exp = os.path.join(os.environ["EXP_PATH"], exp)
                    if os.path.isfile(exp):
                        experience = exp
                        break

            exe_path = os.environ["CARB_APP_PATH"]

            argv = [
                os.path.abspath(experience),
                # run as portable to prevent writing extra files to user directory
                "--portable",
                # extensions
                # extensions: adding to json doesn't work
                "--ext-folder", os.path.abspath(os.path.join(os.environ["ISAAC_PATH"], "exts")),
                # extensions: so we can reference other kit files  
                "--ext-folder", os.path.abspath(os.path.join(os.environ["ISAAC_PATH"], "apps")),      
                # ...      
                f"--/app/tokens/exe-path={os.path.abspath(exe_path)}",  # this is needed so dlss lib is found
                # "--/app/fastShutdown=true",
                "--/app/installSignalHandlers=false",
                "--/app/python/interceptSysStdOutput=false",
                "--/app/python/interceptSysExit=false",
                "--/app/python/logSysStdOutput=false",
                "--/app/python/enableGCProfiling=false",
                "--/app/python/disableGCDuringStartup=false",
                # logging
                # logging: disable default log file creation
                "--/log/file=",
                # "--/log/enabled=false",
                # *argv,
            ]

            self._app_framework = AppFramework(argv=argv)

            import isaacsim
            import omni
            import pxr

            self._isaacsim = isaacsim
            self._omni = omni
            self._pxr = pxr

            # TODO load extensions

        # TODO !!!!!
        self._should_run_loop = False

    @property
    def isaacsim(self):
        # TODO !!!!
        return self._isaacsim

    @property
    def omni(self):
        # TODO !!!!
        return self._omni

    @property
    def pxr(self):
        # TODO !!!!
        return self._pxr
    
    def start_loop_soon(
        self, 
        main_loop: asyncio.AbstractEventLoop = None,
    ):
        if main_loop is None:
            main_loop = asyncio.get_running_loop()

        def f():
            if not self._should_run_loop:
                return
            self._app_framework.update()
            main_loop.call_soon(f)
        
        self._should_run_loop = True
        main_loop.call_soon(f)

    def stop_loop_soon(self):
        self._should_run_loop = False

    def step_loop(self):
        return self._app_framework.update()

# %%
kernel = Kernel()
# Out:
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# Loading user config located at: '/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Full/5.0/user.config.json'
# 2025-09-10T08:10:49Z s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.055s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.231s] [ext: omni.metrics.core-0.0.3] startup
# [0.231s] [ext: omni.client.lib-1.1.0] startup
# [0.244s] [ext: omni.blobkey-1.1.2] startup
# [0.244s] [ext: omni.stats-1.0.1] startup
# [0.245s] [ext: omni.datastore-0.0.0] startup
# [0.249s] [ext: omni.client-1.3.0] startup
# [0.305s] [ext: omni.ujitso.default-1.0.0] startup
# [0.307s] [ext: omni.hsscclient-1.1.2] startup
# [0.310s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.311s] [ext: omni.assets.plugins-0.0.0] startup
# [0.312s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.318s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.329s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 535.247.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3060          | Yes: 0 |     | 12288   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2504      | 3157457f.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 12 (bookworm) debian, Version: 12.00.0, Kernel: 6.1.0-35-amd64
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101007 (1.21.1.7)
# | Processor: 12th Gen Intel(R) Core(TM) i5-12400F
# | Cores: 6 | Logical Cores: 12
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 23868 | Free Memory: 12891
# | Total Page/Swap (MB): 16383 | Free Page/Swap: 13338
# |---------------------------------------------------------------------------------------------|
# 2025-09-10T08:10:50Z s] [Warning] [gpu.foundation.plugin] CPU performance profile is set to powersave. This profile sets the CPU to the lowest frequency reducing performance.
# 2025-09-10T08:10:50Z s] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# [0.807s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.808s] [ext: omni.materialx.libs-1.0.7] startup
# [0.815s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.816s] [ext: omni.usd.config-1.0.6] startup
# [0.818s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.819s] [ext: omni.usd.libs-1.0.1] startup
# [0.891s] [ext: omni.mdl-56.0.3] startup
# [0.980s] [ext: omni.iray.libs-0.0.0] startup
# [0.986s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [0.990s] [ext: omni.kit.usd.mdl-1.1.4] startup
# [1.087s] [ext: omni.kit.telemetry-0.5.2] startup
# [1.105s] [ext: omni.pip.compute-1.6.2] startup
# [1.106s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [1.107s] [ext: omni.kit.test-2.0.1] startup
# [1.136s] [ext: omni.appwindow-1.1.10] startup
# [1.717s] [ext: omni.kit.renderer.core-1.1.0] startup
# [6.109s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [6.111s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [6.173s] [ext: omni.ui-2.26.18] startup
# [6.181s] [ext: omni.kit.mainwindow-1.0.3] startup
# [6.182s] [ext: carb.audio-0.1.0] startup
# [6.185s] [ext: omni.uiaudio-1.0.0] startup
# [6.185s] [ext: omni.kit.uiapp-0.0.0] startup
# [6.185s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [6.187s] [ext: omni.usd.schema.audio-0.0.0] startup
# [6.190s] [ext: omni.usd.schema.isaac-3.0.5] startup
# [6.190s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [6.192s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [6.194s] [ext: omni.usd.schema.anim-0.0.0] startup
# [6.210s] [ext: usdrt.scenegraph-7.6.1] startup
# [6.277s] [ext: omni.activity.core-1.0.3] startup
# [6.278s] [ext: omni.kit.actions.core-1.0.0] startup
# [6.280s] [ext: omni.usd_resolver-1.0.0] startup
# [6.283s] [ext: omni.kit.commands-1.4.10] startup
# [6.286s] [ext: omni.usd.core-1.5.3] startup
# [6.288s] [ext: omni.resourcemonitor-107.0.1] startup
# [6.290s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [6.291s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [6.296s] [ext: omni.kit.usd_undo-0.1.8] startup
# [6.297s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [6.300s] [ext: omni.graph.exec-0.9.6] startup
# [6.300s] [ext: omni.timeline-1.0.14] startup
# [6.302s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [6.303s] [ext: omni.kit.exec.core-0.13.4] startup
# [6.305s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [6.308s] [ext: omni.usd-1.13.10] startup
# 2025-09-10T08:10:56Z [6,316ms] [Warning] [omni.usd.audio] failed to subscribe to stage events
# [6.345s] [ext: omni.kit.asset_converter-5.0.12] startup
# [6.354s] [ext: isaacsim.robot.schema-3.5.1] startup
# [6.361s] [ext: omni.anim.navigation.schema-107.3.0] startup
# [6.364s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [6.369s] [ext: omni.inspect-1.0.2] startup
# [6.370s] [ext: omni.kit.notification_manager-1.0.10] startup
# [6.371s] [ext: omni.graph.core-2.184.3] startup
# [6.374s] [ext: isaacsim.core.deprecation_manager-0.2.7] startup
# [6.374s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [6.375s] [ext: omni.pip.cloud-1.3.6] startup
# [6.377s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [6.380s] [ext: omni.anim.graph.schema-107.3.0] startup
# [6.385s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [6.386s] [ext: omni.usd.schema.physx-107.3.18] startup
# [6.414s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [6.415s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [6.415s] [ext: omni.usd.schema.flow-107.1.1] startup
# [6.416s] [ext: omni.index.libs-380600.5717.0] startup
# [6.416s] [ext: omni.index-1.0.1] startup
# [6.416s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [6.417s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [6.418s] [ext: omni.kit.widget.nucleus_info-2.0.2] startup
# [6.419s] [ext: omni.kit.menu.core-1.1.2] startup
# [6.420s] [ext: omni.kit.widget.filebrowser-2.12.2] startup
# [6.423s] [ext: omni.kit.search_core-1.0.8] startup
# [6.424s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [6.426s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [6.427s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [6.428s] [ext: omni.kit.widget.search_delegate-1.0.7] startup
# [6.429s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [6.429s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [6.430s] [ext: omni.ui.scene-1.11.4] startup
# [6.434s] [ext: omni.kit.widget.versioning-1.4.10] startup
# [6.436s] [ext: omni.kit.clipboard-1.0.5] startup
# [6.437s] [ext: omni.kit.collaboration.telemetry-1.1.0] startup
# [6.438s] [ext: omni.kit.window.filepicker-2.13.3] startup
# [6.445s] [ext: omni.kit.collaboration.channel_manager-1.0.14] startup
# [6.446s] [ext: omni.volume-0.5.2] startup
# [6.466s] [ext: omni.ujitso.client-0.0.0] startup
# [6.466s] [ext: omni.kit.usd.layers-2.2.10] startup
# [6.473s] [ext: omni.hydra.rtx-1.0.0] startup
# 2025-09-10T08:10:56Z [6,467ms] [Warning] [omni.log] Source: omni.hydra was already registered.
# [6.500s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [6.502s] [ext: omni.kit.menu.utils-2.0.3] startup
# [6.509s] [ext: omni.kit.context_menu-1.8.6] startup
# [6.511s] [ext: omni.kit.raycast.query-1.1.0] startup
# [6.515s] [ext: omni.kit.material.library-2.0.7] startup
# [6.519s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [6.521s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [6.526s] [ext: omni.kit.hydra_texture-1.4.5] startup
# [6.528s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [6.529s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [6.530s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [6.533s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [6.533s] [ext: omni.kit.viewport.legacy_gizmos-1.0.18] startup
# [6.535s] [ext: omni.kit.widget.settings-1.2.3] startup
# [6.537s] [ext: omni.kit.viewport.window-107.0.12] startup
# [6.551s] [ext: omni.kit.window.preferences-1.8.0] startup
# [6.560s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [6.562s] [ext: omni.kit.widget.filter-1.1.4] startup
# [6.563s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [6.563s] [ext: omni.kit.manipulator.transform-107.0.0] startup
# [6.568s] [ext: omni.graph.tools-1.79.2] startup
# [6.589s] [ext: omni.kit.widget.text_editor-1.1.1] startup
# [6.590s] [ext: omni.graph-1.141.2] startup
# [6.626s] [ext: omni.kit.window.extensions-1.4.26] startup
# [6.632s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [6.633s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [6.634s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [6.636s] [ext: omni.kit.widget.live_session_management.ui-1.0.3] startup
# [6.639s] [ext: omni.kit.collaboration.presence_layer-1.1.2] startup
# [6.685s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [6.686s] [ext: omni.kit.widget.stage-3.1.4] startup
# [6.696s] [ext: omni.kit.widget.live_session_management-1.2.23] startup
# [6.698s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [6.699s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [6.701s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [6.702s] [ext: omni.kit.window.file-2.0.5] startup
# [6.705s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [6.706s] [ext: omni.kit.window.property-1.12.1] startup
# [6.708s] [ext: omni.kit.window.content_browser-3.1.1] startup
# [6.719s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [6.721s] [ext: omni.kit.widget.toolbar-2.0.1] startup
# [6.727s] [ext: omni.kit.property.usd-4.5.11] startup
# [6.738s] [ext: omni.kit.manipulator.tool.snap-1.5.13] startup
# [6.743s] [ext: omni.kit.manipulator.selector-1.1.3] startup
# [6.744s] [ext: isaacsim.core.version-2.0.6] startup
# [6.745s] [ext: omni.ui_query-1.1.8] startup
# [6.747s] [ext: isaacsim.storage.native-1.2.8] startup
# [6.748s] [ext: omni.graph.ui-1.101.7] startup
# [6.767s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [6.771s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [6.772s] [ext: omni.graph.scriptnode-1.50.0] startup
# [6.773s] [ext: omni.kvdb-107.3.18] startup
# [6.777s] [ext: omni.kit.manipulator.prim.core-107.0.8] startup
# [6.791s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [6.794s] [ext: omni.physx.foundation-107.3.18] startup
# [6.796s] [ext: omni.localcache-107.3.18] startup
# [6.798s] [ext: omni.convexdecomposition-107.3.18] startup
# [6.800s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [6.802s] [ext: omni.fabric.commands-1.1.6] startup
# [6.805s] [ext: omni.usdphysics-107.3.18] startup
# [6.806s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [6.808s] [ext: omni.physx.cooking-107.3.18] startup
# [6.811s] [ext: omni.physics-107.3.18] startup
# [6.814s] [ext: omni.kit.window.cursor-1.1.4] startup
# [6.815s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [6.815s] [ext: omni.debugdraw-0.1.4] startup
# [6.818s] [ext: omni.physx-107.3.18] startup
# [6.828s] [ext: omni.physics.stageupdate-107.3.18] startup
# [6.830s] [ext: omni.kit.viewport.menubar.core-107.1.5] startup
# [6.844s] [ext: omni.kit.viewport.actions-107.0.2] startup
# [6.847s] [ext: omni.kit.widget.layers-1.8.6] startup
# [6.858s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [6.859s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [6.861s] [ext: omni.kit.widget.graph-2.0.0] startup
# [6.866s] [ext: omni.usdphysics.ui-107.3.18] startup
# [6.889s] [ext: omni.physx.commands-107.3.18] startup
# [6.896s] [ext: omni.physics.tensors-107.3.18] startup
# [6.900s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [6.901s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# [6.905s] [ext: omni.physx.ui-107.3.18] startup
# [6.928s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [6.930s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [6.933s] [ext: omni.warp.core-1.8.1] startup
# [7.147s] [ext: omni.usd.metrics.assembler.physics-107.3.18] startup
# [7.149s] [ext: omni.physics.physx-107.3.18] startup
# [7.150s] [ext: omni.kit.numpy.common-0.1.2] startup
# [7.152s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [7.154s] [ext: omni.isaac.dynamic_control-2.0.7] startup
# 2025-09-10T08:10:56Z [7,140ms] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# [7.160s] [ext: omni.kit.window.material_graph-1.8.23] startup
# [7.185s] [ext: omni.graph.image.core-0.6.1] startup
# [7.187s] [ext: isaacsim.core.utils-3.4.5] startup
# [7.189s] [ext: omni.kit.stage_templates-2.0.0] startup
# [7.192s] [ext: omni.graph.action_core-1.1.7] startup
# [7.194s] [ext: omni.kit.widget.stage_icons-1.0.8] startup
# [7.195s] [ext: omni.physx.tensors-107.3.18] startup
# [7.198s] [ext: isaacsim.test.docstring-1.1.0] startup
# [7.201s] [ext: isaacsim.core.simulation_manager-1.3.2] startup
# [8.596s] [ext: isaacsim.core.experimental.utils-0.2.0] startup
# [8.599s] [ext: omni.graph.action_nodes_core-1.2.0] startup
# [8.601s] [ext: omni.kit.window.stage-2.6.1] startup
# [8.605s] [ext: isaacsim.core.experimental.prims-0.6.2] startup
# [8.625s] [ext: omni.graph.action_nodes-1.51.0] startup
# [8.628s] [ext: omni.kit.menu.stage-1.2.7] startup
# [8.630s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [8.651s] [ext: omni.graph.action-1.130.0] startup
# [8.651s] [ext: omni.kit.widget.zoombar-1.0.7] startup
# [8.654s] [ext: omni.kit.usd.collect-2.4.5] startup
# [8.658s] [ext: omni.kit.browser.core-2.3.16] startup
# [8.666s] [ext: omni.kit.tool.collect-2.2.18] startup
# [8.668s] [ext: omni.kit.browser.folder.core-1.10.10] startup
# [8.674s] [ext: omni.kit.usdz_export-1.0.9] startup
# [8.677s] [ext: omni.kit.ui_test-1.3.6] startup
# [8.678s] [ext: omni.kit.tool.asset_importer-4.3.2] startup
# [8.683s] [ext: isaacsim.gui.components-1.1.9] startup
# [8.686s] [ext: isaacsim.examples.browser-0.1.12] startup
# [8.691s] [ext: isaacsim.asset.importer.urdf-2.4.19] startup
# [8.744s] [ext: isaacsim.core.prims-0.5.1] startup
# [8.767s] [ext: omni.graph.image.nodes-1.3.1] startup
# [8.769s] [ext: isaacsim.core.experimental.materials-0.3.0] startup
# [8.771s] [ext: omni.graph.nodes_core-1.1.0] startup
# [8.776s] [ext: isaacsim.core.api-4.6.10] startup
# [8.784s] [ext: omni.kit.selection-0.1.6] startup
# [8.787s] [ext: omni.graph.nodes-1.171.0] startup
# [8.793s] [ext: omni.kit.widget.imageview-1.0.4] startup
# [8.794s] [ext: isaacsim.robot.surface_gripper-3.2.6] startup
# [8.797s] [ext: isaacsim.gui.menu-2.3.17] startup
# [9.314s] [ext: omni.graph.ui_nodes-1.50.8] startup
# [9.319s] [ext: omni.videoencoding-0.1.2] startup
# [9.322s] [ext: omni.syntheticdata-0.6.13] startup
# [9.336s] [ext: isaacsim.robot.surface_gripper.ui-3.0.2] startup
# [9.342s] [ext: omni.warp-1.8.1] startup
# [9.349s] [ext: omni.kit.window.quicksearch-2.4.4] startup
# [9.361s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [9.365s] [ext: omni.kit.graph.delegate.modern-1.10.8] startup
# [9.369s] [ext: omni.replicator.core-1.12.17] startup
# 2025-09-10T08:10:59Z [9,366ms] [Warning] [pxr.Semantics] pxr.Semantics is deprecated - please use Semantics instead
# Warp 1.8.1 initialized:
#    CUDA Toolkit 12.8, Driver 12.2
#    Devices:
#      "cpu"      : "CPU"
#      "cuda:0"   : "NVIDIA GeForce RTX 3060" (12 GiB, sm_86, mempool enabled)
#    Kernel cache:
#      /home/sysadmin/.cache/warp/1.8.1
# 2025-09-10T08:10:59Z [9,618ms] [Warning] [omni.replicator.core.scripts.extension] No material configuration file, adding configuration to material settings directly.
# [9.641s] [ext: omni.graph.window.core-2.0.0] startup
# [9.657s] [ext: isaacsim.core.nodes-3.2.16] startup
# [9.665s] [ext: omni.graph.window.generic-1.50.2] startup
# [9.676s] [ext: isaacsim.sensors.camera-1.3.1] startup
# [9.684s] [ext: isaacsim.core.throttling-2.1.10] startup
# [9.690s] [ext: isaacsim.sensors.camera.ui-0.2.0] startup
# [9.691s] [ext: isaacsim.sensors.physics-0.3.27] startup
# [9.701s] [ext: omni.anim.navigation.core-107.3.0] startup
# [9.712s] [ext: isaacsim.robot.policy.examples-4.1.11] startup
# [9.716s] [ext: omni.anim.navigation.meshtools-107.3.0] startup
# [9.733s] [ext: omni.isaac.quadruped-3.0.7] startup
# 2025-09-10T08:10:59Z [9,714ms] [Warning] [omni.isaac.quadruped] omni.isaac.quadruped has been deprecated in favor of isaacsim.robot.policy.examples. Please update your code accordingly.
# [9.735s] [ext: isaacsim.robot_motion.lula-4.0.8] startup
# [9.746s] [ext: isaacsim.asset.browser-1.3.19] startup
# [9.751s] [ext: isaacsim.robot.manipulators-3.3.5] startup
# [9.760s] [ext: isaacsim.robot_motion.motion_generation-8.0.25] startup
# [9.787s] [ext: omni.isaac.asset_browser-1.0.6] startup
# 2025-09-10T08:10:59Z [9,769ms] [Warning] [omni.isaac.asset_browser] omni.isaac.asset_browser has been deprecated in favor of isaacsim.asset.browser. Please update your code accordingly.
# [9.789s] [ext: isaacsim.core.cloner-1.4.9] startup
# [9.796s] [ext: isaacsim.robot.manipulators.examples-1.0.17] startup
# [9.798s] [ext: omni.isaac.assets_check-0.3.13] startup
# 2025-09-10T08:10:59Z [9,780ms] [Warning] [omni.isaac.assets_check] omni.isaac.assets_check has been deprecated in favor of isaacsim.asset.browser. Please update your code accordingly.
# [9.800s] [ext: omni.isaac.cloner-1.0.7] startup
# 2025-09-10T08:10:59Z [9,782ms] [Warning] [omni.isaac.cloner] omni.isaac.cloner has been deprecated in favor of isaacsim.core.cloner. Please update your code accordingly.
# [9.803s] [ext: isaacsim.cortex.framework-1.0.12] startup
# [9.806s] [ext: omni.isaac.core-4.0.7] startup
# 2025-09-10T08:10:59Z [9,791ms] [Warning] [omni.isaac.core.physics_context.physics_context] omni.isaac.core.physics_context.physics_context has been deprecated in favor of isaacsim.core.api.physics_context.physics_context. Please update your code accordingly.
# 2025-09-10T08:10:59Z [9,794ms] [Warning] [omni.isaac.core.simulation_context.simulation_context] omni.isaac.core.simulation_context.simulation_context has been deprecated in favor of isaacsim.core.api.simulation_context.simulation_context. Please update your code accordingly.
# 2025-09-10T08:10:59Z [9,794ms] [Warning] [omni.isaac.core.world.world] omni.isaac.core.world.world has been deprecated in favor of isaacsim.core.api.world.world. Please update your code accordingly.
# 2025-09-10T08:10:59Z [9,794ms] [Warning] [omni.isaac.core] omni.isaac.core has been deprecated in favor of isaacsim.core.api. Please update your code accordingly.
# [9.815s] [ext: isaacsim.core.experimental.objects-0.2.4] startup
# [9.857s] [ext: isaacsim.cortex.behaviors-2.0.12] startup
# [9.861s] [ext: omni.isaac.cortex-1.0.5] startup
# 2025-09-10T08:10:59Z [9,845ms] [Warning] [omni.isaac.cortex] omni.isaac.cortex has been deprecated in favor of isaacsim.cortex.framework. Please update your code accordingly.
# [9.865s] [ext: isaacsim.simulation_app-2.9.2] startup
# [9.865s] [ext: omni.isaac.cortex.sample_behaviors-2.0.5] startup
# 2025-09-10T08:10:59Z [9,850ms] [Warning] [omni.isaac.cortex.sample_behaviors] omni.isaac.cortex.sample_behaviors has been deprecated in favor of isaacsim.cortex.behaviors. Please update your code accordingly.
# [9.872s] [ext: omni.kit.viewport.menubar.render-107.0.9] startup
# [9.902s] [ext: omni.isaac.kit-2.0.6] startup
# 2025-09-10T08:10:59Z [9,884ms] [Warning] [omni.isaac.kit] omni.isaac.kit has been deprecated in favor of isaacsim.simulation_app. Please update your code accordingly.
# [9.907s] [ext: omni.sensors.nv.common-2.7.0-coreapi] startup
# [9.959s] [ext: omni.isaac.franka-1.0.7] startup
# 2025-09-10T08:10:59Z [9,940ms] [Warning] [omni.isaac.franka] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.franka. Please update your code accordingly.
# 2025-09-10T08:10:59Z [9,941ms] [Warning] [omni.isaac.franka.franka] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.franka. Please update your code accordingly.
# 2025-09-10T08:10:59Z [9,946ms] [Warning] [omni.isaac.franka.kinematics_solver] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.franka. Please update your code accordingly.
# [9.965s] [ext: omni.isaac.lula-4.0.6] startup
# 2025-09-10T08:10:59Z [9,948ms] [Warning] [omni.isaac.lula] omni.isaac.lula has been deprecated in favor of isaacsim.robot_motion.lula. Please update your code accordingly.
# [9.969s] [ext: isaacsim.robot_motion.lula_test_widget-1.0.12] startup
# [10.017s] [ext: omni.sensors.nv.materials-1.6.0-coreapi] startup
# [10.046s] [ext: omni.sensors.nv.wpm-2.5.0-coreapi] startup
# [10.050s] [ext: omni.sensors.net-0.4.0-coreapi] startup
# [10.064s] [ext: omni.isaac.lula_test_widget-1.0.6] startup
# 2025-09-10T08:10:59Z [10,047ms] [Warning] [omni.isaac.lula_test_widget] omni.isaac.lula_test_widget has been deprecated in favor of isaacsim.robot_motion.lula_test_widget. Please update your code accordingly.
# [10.068s] [ext: isaacsim.util.debug_draw-3.1.0] startup
# [10.095s] [ext: omni.sensors.nv.radar-2.8.0-coreapi] startup
# [10.150s] [ext: omni.sensors.nv.lidar-2.7.0-coreapi] startup
# [10.167s] [ext: omni.sensors.nv.ids-1.5.0-coreapi] startup
# [10.182s] [ext: isaacsim.gui.sensors.icon-2.0.3] startup
# [10.360s] [ext: isaacsim.sensors.physx-2.2.27] startup
# Warp DeprecationWarning: The `warp.sim` module is deprecated and will be removed in v1.10. Please transition to using the forthcoming Newton library instead.
# [10.386s] [ext: isaacsim.sensors.rtx-15.5.0] startup
# [10.400s] [ext: isaacsim.gui.content_browser-0.1.9] startup
# [10.410s] [ext: omni.isaac.range_sensor-4.0.6] startup
# 2025-09-10T08:11:00Z [10,392ms] [Warning] [omni.isaac.range_sensor] omni.isaac.range_sensor has been deprecated in favor of isaacsim.sensors.physx. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,392ms] [Warning] [omni.isaac.range_sensor.commands] omni.isaac.range_sensor.commands has been deprecated in favor of isaacsim.sensors.physx.commands. Please update your code accordingly.
# [10.412s] [ext: omni.isaac.sensor-13.0.7] startup
# 2025-09-10T08:11:00Z [10,394ms] [Warning] [omni.isaac.sensor] omni.isaac.sensor has been deprecated in favor of isaacsim.sensors.camera, isaacsim.sensors.physics, isaacsim.sensors.physx, and isaacsim.sensors.rtx. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,395ms] [Warning] [omni.isaac.sensor.camera] omni.isaac.sensor.camera has been deprecated in favor of isaacsim.sensors.camera.camera. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,396ms] [Warning] [omni.isaac.sensor.camera_view] omni.isaac.sensor.camera_view has been deprecated in favor of isaacsim.sensors.camera.camera_view. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,396ms] [Warning] [omni.isaac.sensor.commands] omni.isaac.sensor.commands has been deprecated in favor of isaacsim.sensors.physics.commands, isaacsim.sensors.physx.commands, and isaacsim.sensors.rtx.commands. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,398ms] [Warning] [omni.isaac.sensor.contact_sensor] omni.isaac.sensor.contact_sensor has been deprecated in favor of isaacsim.sensors.physics.contact_sensor. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,400ms] [Warning] [omni.isaac.sensor.imu_sensor] omni.isaac.sensor.imu_sensor has been deprecated in favor of isaacsim.sensors.physics.imu_sensor. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,405ms] [Warning] [omni.isaac.sensor.lidar_rtx] omni.isaac.sensor.lidar_rtx has been deprecated in favor of isaacsim.sensors.rtx.lidar_rtx. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,405ms] [Warning] [omni.isaac.sensor.rotating_lidar_physX] omni.isaac.sensor.imu_sensor has been deprecated in favor of isaacsim.sensors.physix.rotating_lidar_physX. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,406ms] [Warning] [omni.isaac.sensor.scripts.samples.contact_sensor] omni.isaac.sensor.scripts.samples.contact_sensor has been deprecated in favor of isaacsim.sensors.physics.scripts.samples.contact_sensor. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,407ms] [Warning] [omni.isaac.sensor.scripts.samples.imu_sensor] omni.isaac.sensor.scripts.samples.imu_sensor has been deprecated in favor of isaacsim.sensors.physics.scripts.samples.imu_sensor. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,409ms] [Warning] [omni.isaac.sensor.scripts.samples.lightbeam_sensor] omni.isaac.sensor.scripts.samples.lightbeam_sensor has been deprecated in favor of isaacsim.sensors.physx.scripts.samples.lightbeam_sensor. Please update your code accordingly.
# [10.430s] [ext: isaacsim.robot.wheeled_robots-4.0.23] startup
# [10.450s] [ext: omni.isaac.surface_gripper-2.0.6] startup
# 2025-09-10T08:11:00Z [10,434ms] [Warning] [omni.isaac.surface_gripper] omni.isaac.surface_gripper has been deprecated in favor of isaacsim.robot.surface_gripper. Please update your code accordingly.
# [10.454s] [ext: omni.isaac.universal_robots-1.0.6] startup
# 2025-09-10T08:11:00Z [10,436ms] [Warning] [omni.isaac.universal_robots] omni.isaac.universal_robots has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,437ms] [Warning] [omni.isaac.universal_robots.kinematics_solver] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,440ms] [Warning] [omni.isaac.universal_robots.ur10] omni.isaac.franka has been deprecated in favor of isaacsim.robot.manipulators.examples.universal_robots. Please update your code accordingly.
# [10.460s] [ext: omni.isaac.utils-2.0.6] startup
# [10.463s] [ext: omni.isaac.version-2.0.7] startup
# 2025-09-10T08:11:00Z [10,446ms] [Warning] [omni.isaac.version] omni.isaac.version has been deprecated in favor of isaacsim.core.version. Please update your code accordingly.
# [10.466s] [ext: omni.isaac.wheeled_robots-3.0.7] startup
# 2025-09-10T08:11:00Z [10,448ms] [Warning] [omni.isaac.wheeled_robots] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,449ms] [Warning] [omni.isaac.wheeled_robots.controllers] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,450ms] [Warning] [omni.isaac.wheeled_robots.controllers.ackermann_controller] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,451ms] [Warning] [omni.isaac.wheeled_robots.controllers.differential_controller] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,452ms] [Warning] [omni.isaac.wheeled_robots.controllers.holonomic_controller] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,452ms] [Warning] [omni.isaac.wheeled_robots.controllers.quintic_path_planner] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,452ms] [Warning] [omni.isaac.wheeled_robots.controllers.stanley_control] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,452ms] [Warning] [omni.isaac.wheeled_robots.controllers.wheel_base_pose_controller] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,453ms] [Warning] [omni.isaac.wheeled_robots.impl] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,453ms] [Warning] [omni.isaac.wheeled_robots.robots] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,453ms] [Warning] [omni.isaac.wheeled_robots.robots.holonomic_robot_usd_setup] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,456ms] [Warning] [omni.isaac.wheeled_robots.robots.wheeled_robot] omni.isaac.wheeled_robots has been deprecated in favor of isaacsim.robot.wheeled_robots. Please update your code accordingly.
# [10.476s] [ext: omni.kit.menu.create-2.0.1] startup
# [10.482s] [ext: omni.kit.property.audio-1.0.16] startup
# [10.488s] [ext: omni.kit.property.camera-1.0.10] startup
# [10.492s] [ext: omni.kit.property.geometry-2.0.4] startup
# [10.499s] [ext: omni.hydra.scene_api-0.1.2] startup
# [10.506s] [ext: omni.kit.property.light-1.0.12] startup
# [10.520s] [ext: isaacsim.app.about-2.0.11] startup
# [10.524s] [ext: omni.kit.property.material-1.11.9] startup
# [10.537s] [ext: omni.kit.property.render-1.2.1] startup
# [10.545s] [ext: omni.kit.property.transform-1.5.12] startup
# [10.548s] [ext: isaacsim.gui.property-1.1.3] startup
# [10.550s] [ext: omni.isaac.window.about-2.0.7] startup
# 2025-09-10T08:11:00Z [10,531ms] [Warning] [omni.isaac.window.about] omni.isaac.window.about has been deprecated in favor of isaacsim.app.about. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,531ms] [Warning] [omni.isaac.window.about.about] omni.isaac.window.about.about has been deprecated in favor of isaacsim.app.about.about. Please update your code accordingly.
# [10.551s] [ext: omni.kit.manipulator.camera-106.0.4] startup
# [10.556s] [ext: omni.isaac.core_nodes-2.0.6] startup
# 2025-09-10T08:11:00Z [10,538ms] [Warning] [omni.isaac.core_nodes] omni.isaac.core_nodes has been deprecated in favor of isaacsim.core.nodes. Please update your code accordingly.
# [10.558s] [ext: omni.kit.property.bundle-1.4.1] startup
# [10.566s] [ext: omni.kit.property.isaac-1.0.6] startup
# 2025-09-10T08:11:00Z [10,550ms] [Warning] [omni.kit.property.isaac] omni.kit.property.isaac has been deprecated in favor of isaacsim.gui.property. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,551ms] [Warning] [omni.kit.property.isaac.widgets] omni.kit.property.isaac.widgets has been deprecated in favor of isaacsim.gui.property.widgets. Please update your code accordingly.
# [10.571s] [ext: omni.kit.scripting-107.3.1] startup
# [10.580s] [ext: omni.isaac.manipulators-3.0.7] startup
# 2025-09-10T08:11:00Z [10,561ms] [Warning] [omni.isaac.manipulators] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,561ms] [Warning] [omni.isaac.manipulators.controllers] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,561ms] [Warning] [omni.isaac.manipulators.controllers.pick_place_controller] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,562ms] [Warning] [omni.isaac.manipulators.controllers.stacking_controller] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,564ms] [Warning] [omni.isaac.manipulators.grippers] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,565ms] [Warning] [omni.isaac.manipulators.grippers.gripper] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,565ms] [Warning] [omni.isaac.manipulators.grippers.parallel_gripper] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,565ms] [Warning] [omni.isaac.manipulators.grippers.surface_gripper] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,565ms] [Warning] [omni.isaac.manipulators.manipulators] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,565ms] [Warning] [omni.isaac.manipulators.manipulators.single_manipulator] omni.isaac.manipulators has been deprecated in favor of isaacsim.robot.manipulators. Please update your code accordingly.
# [10.586s] [ext: omni.kit.viewport.menubar.camera-107.0.3] startup
# [10.597s] [ext: omni.kit.viewport.menubar.lighting-107.3.1] startup
# [10.600s] [ext: isaacsim.replicator.writers-1.0.15] startup
# [10.620s] [ext: omni.isaac.menu-1.0.6] startup
# 2025-09-10T08:11:00Z [10,602ms] [Warning] [omni.isaac.menu] omni.isaac.menu has been deprecated in favor of isaacsim.gui.menu. Please update your code accordingly.
# [10.622s] [ext: isaacsim.replicator.behavior-1.1.14] startup
# [10.627s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [10.635s] [ext: omni.kit.window.console-1.1.4] startup
# [10.640s] [ext: isaacsim.replicator.domain_randomization-1.0.16] startup
# [10.642s] [ext: isaacsim.replicator.examples-1.1.31] startup
# [10.645s] [ext: omni.ocio-0.1.1] startup
# [10.648s] [ext: omni.rtx.window.settings-0.6.19] startup
# [10.659s] [ext: omni.kit.window.status_bar-0.1.8] startup
# [10.671s] [ext: omni.kit.window.toolbar-2.0.0] startup
# [10.674s] [ext: omni.replicator.isaac-2.0.8] startup
# 2025-09-10T08:11:00Z [10,655ms] [Warning] [omni.replicator.isaac] omni.replicator.isaac has been deprecated in favor of isaacsim.replicator.domain_randomization, isaacsim.replicator.examples, isaacsim.replicator.writers. Please update your code accordingly.
# [10.675s] [ext: omni.replicator.replicator_yaml-2.0.11] startup
# [10.692s] [ext: omni.rtx.settings.core-0.6.5] startup
# [10.697s] [ext: omni.usd.metrics.assembler.ui-107.3.1] startup
# [10.709s] [ext: omni.isaac.motion_generation-8.0.7] startup
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.articulation_kinematics_solver] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.articulation_motion_policy] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.articulation_trajectory] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.kinematics_interface] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.lula] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.lula.kinematics] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.lula.motion_policies] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.lula.path_planners] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,691ms] [Warning] [omni.isaac.motion_generation.lula.trajectory_generator] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,692ms] [Warning] [omni.isaac.motion_generation.motion_policy_controller] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,692ms] [Warning] [omni.isaac.motion_generation.motion_policy_interface] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,692ms] [Warning] [omni.isaac.motion_generation.path_planner_visualizer] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,692ms] [Warning] [omni.isaac.motion_generation.path_planning_interface] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,692ms] [Warning] [omni.isaac.motion_generation.trajectory] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,692ms] [Warning] [omni.isaac.motion_generation.world_interface] omni.isaac.motion_generation has been deprecated in favor of isaacsim.robot_motion.motion_generation. Please update your code accordingly.
# [10.712s] [ext: semantics.schema.editor-2.0.1] startup
# [10.717s] [ext: isaacsim.examples.extension-2.0.12] startup
# [10.719s] [ext: omni.kit.ui.actions-1.0.5] startup
# [10.722s] [ext: semantics.schema.property-2.0.1] startup
# [10.723s] [ext: omni.isaac.nucleus-1.0.6] startup
# 2025-09-10T08:11:00Z [10,705ms] [Warning] [omni.isaac.nucleus] omni.isaac.nucleus has been deprecated in favor of isaacsim.storage.native. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,705ms] [Warning] [omni.isaac.nucleus.nucleus] omni.isaac.nucleus.nucleus has been deprecated in favor of isaacsim.storage.native. Please update your code accordingly.
# [10.725s] [ext: omni.anim.curve.core-1.3.1] startup
# [10.736s] [ext: isaacsim.asset.importer.mjcf-2.5.8] startup
# [10.741s] [ext: isaacsim.examples.interactive-4.6.10] startup
# [10.759s] [ext: omni.kit.menu.common-2.0.0] startup
# [10.769s] [ext: isaacsim.exp.base-5.0.0] startup
# [10.770s] [ext: omni.kit.stage.copypaste-1.2.4] startup
# [10.784s] [ext: isaacsim.sensors.physics.ui-0.1.12] startup
# [10.792s] [ext: isaacsim.sensors.physics.examples-0.1.15] startup
# [10.799s] [ext: isaacsim.replicator.behavior.ui-1.0.5] startup
# [10.808s] [ext: omni.anim.curve.ui-1.4.1] startup
# [10.812s] [ext: isaacsim.robot.manipulators.ui-2.1.22] startup
# [10.814s] [ext: isaacsim.util.physics-1.1.5] startup
# [10.820s] [ext: omni.anim.curve.bundle-1.2.3] startup
# [10.820s] [ext: omni.kit.browser.asset-1.3.12] startup
# [10.824s] [ext: omni.anim.shared.core-107.0.1] startup
# [10.829s] [ext: isaacsim.robot.wheeled_robots.ui-2.1.23] startup
# [10.831s] [ext: isaacsim.asset.importer.heightmap-2.0.6] startup
# [10.837s] [ext: omni.graph.window.action-1.50.2] startup
# [10.846s] [ext: omni.simready.explorer-1.1.3] startup
# [10.856s] [ext: omni.importer.onshape-1.0.0] startup
# [10.870s] [ext: isaacsim.robot_setup.gain_tuner-3.0.5] startup
# [10.880s] [ext: omni.isaac.block_world-2.0.6] startup
# 2025-09-10T08:11:00Z [10,862ms] [Warning] [omni.isaac.block_world] ['omni.isaac.block_world'] has been deprecated in favor of ['isaacsim.asset.importer.heightmap']. Please update your code accordingly.
# [10.882s] [ext: isaacsim.asset.gen.omap-2.0.28] startup
# [10.889s] [ext: isaacsim.robot_setup.grasp_editor-2.0.18] startup
# [10.894s] [ext: omni.isaac.extension_templates-2.0.7] startup
# 2025-09-10T08:11:00Z [10,877ms] [Warning] [omni.isaac.extension_templates] omni.isaac.extension_templates has been deprecated in favor of isaacsim.examples.extension. Please update your code accordingly.
# [10.897s] [ext: omni.isaac.gain_tuner-2.0.5] startup
# [10.898s] [ext: isaacsim.sensors.physx.examples-2.2.15] startup
# [10.900s] [ext: omni.isaac.occupancy_map-2.0.8] startup
# 2025-09-10T08:11:00Z [10,883ms] [Warning] [omni.isaac.occupancy_map] omni.isaac.occupancy_map has been deprecated in favor of isaacsim.asset.gen.omap. Please update your code accordingly.
# [10.903s] [ext: omni.isaac.grasp_editor-2.0.7] startup
# 2025-09-10T08:11:00Z [10,889ms] [Warning] [omni.isaac.grasp_editor] omni.isaac.grasp_editor has been deprecated in favor of isaacsim.robot_setup.grasp_editor. Please update your code accordingly.
# [10.909s] [ext: isaacsim.sensors.rtx.ui-1.1.4] startup
# [10.912s] [ext: isaacsim.robot_setup.assembler-3.0.8] startup
# [10.917s] [ext: isaacsim.robot_setup.xrdf_editor-3.1.11] startup
# [10.922s] [ext: omni.isaac.range_sensor.examples-2.0.6] startup
# 2025-09-10T08:11:00Z [10,904ms] [Warning] [omni.isaac.range_sensor.examples] omni.isaac.range_sensor.examples has been deprecated in favor of isaacsim.sensors.physx.examples. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,905ms] [Warning] [omni.isaac.range_sensor.examples.lidar_info] omni.isaac.range_sensor.examples.lidar_info has been deprecated in favor of isaacsim.sensors.physx.examples.lidar_info. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,905ms] [Warning] [omni.isaac.range_sensor.examples.generic_info] omni.isaac.range_sensor.examples.generic_info has been deprecated in favor of isaacsim.sensors.physx.examples.generic_info. Please update your code accordingly.
# [10.925s] [ext: isaacsim.util.merge_mesh-2.0.15] startup
# [10.931s] [ext: isaacsim.replicator.scene_blox-1.0.8] startup
# 2025-09-10T08:11:00Z [10,914ms] [Warning] [isaacsim.replicator.scene_blox] isacsim.replicator.scene_blox has been deprecated since Isaac Sim 5.0.0.
# [10.933s] [ext: isaacsim.replicator.synthetic_recorder-2.2.15] startup
# [10.938s] [ext: omni.isaac.robot_assembler-2.0.8] startup
# 2025-09-10T08:11:00Z [10,921ms] [Warning] [omni.isaac.robot_assembler] omni.isaac.robot_assembler has been deprecated in favor of isaacsim.robot_setup.assembler. Please update your code accordingly.
# [10.941s] [ext: omni.isaac.robot_description_editor-3.0.5] startup
# [10.942s] [ext: isaacsim.asset.gen.omap.ui-2.2.1] startup
# [10.943s] [ext: omni.kit.actions.window-1.1.3] startup
# [10.950s] [ext: omni.isaac.scene_blox-1.0.6] startup
# 2025-09-10T08:11:00Z [10,932ms] [Warning] [omni.isaac.scene_blox] omni.isaac.scene_blox has been deprecated in favor of isaacsim.replicator.scene_blox. Please update your code accordingly.
# [10.952s] [ext: omni.isaac.synthetic_recorder-2.0.6] startup
# 2025-09-10T08:11:00Z [10,934ms] [Warning] [omni.isaac.synthetic_recorder] omni.isaac.synthetic_recorder has been deprecated in favor of isaacsim.replicator.synthetic_recorder. Please update your code accordingly.
# [10.954s] [ext: omni.isaac.throttling-2.0.7] startup
# 2025-09-10T08:11:00Z [10,936ms] [Warning] [omni.isaac.throttling] omni.isaac.throttling has been deprecated in favor of isaacsim.core.throttling. Please update your code accordingly.
# 2025-09-10T08:11:00Z [10,936ms] [Warning] [omni.isaac.throttling.throttling] omni.isaac.throttling.throttling has been deprecated in favor of isaacsim.core.throttling.extension. Please update your code accordingly.
# [10.956s] [ext: omni.kit.core.collection-0.2.3] startup
# [10.958s] [ext: omni.isaac.occupancy_map.ui-2.0.8] startup
# 2025-09-10T08:11:00Z [10,939ms] [Warning] [omni.isaac.occupancy_map.ui] omni.isaac.occupancy_map.ui has been deprecated in favor of isaacsim.asset.gen.omap.ui. Please update your code accordingly.
# [10.959s] [ext: omni.kit.hotkeys.window-1.4.9] startup
# [10.970s] [ext: omni.kit.mesh.raycast-107.0.1] startup
# [10.974s] [ext: omni.kit.preferences.animation-1.2.0] startup
# [10.978s] [ext: omni.graph.bundle.action-2.30.0] startup
# [10.980s] [ext: omni.kit.property.collection-0.2.3] startup
# [10.983s] [ext: omni.mdl.usd_converter-1.0.30] startup
# [10.987s] [ext: omni.kit.property.layer-1.1.9] startup
# [10.990s] [ext: omni.kit.stagerecorder.core-107.0.3] startup
# [10.995s] [ext: omni.kit.search.files-1.0.4] startup
# [10.997s] [ext: omni.kit.browser.material-1.6.2] startup
# [11.000s] [ext: omni.kit.window.title-1.1.7] startup
# [11.002s] [ext: omni.kit.stage.mdl_converter-1.0.8] startup
# [11.005s] [ext: omni.kit.widgets.custom-1.0.13] startup
# [11.016s] [ext: omni.kit.stagerecorder.ui-107.0.1] startup
# [11.020s] [ext: omni.kit.tool.remove_unused.core-0.1.3] startup
# [11.022s] [ext: omni.kit.window.material-1.6.3] startup
# [11.029s] [ext: omni.kit.stage_column.payload-2.0.3] startup
# [11.031s] [ext: omni.kit.stage_column.variant-1.0.17] startup
# [11.035s] [ext: omni.kit.variant.editor-107.3.0] startup
# [11.051s] [ext: omni.kit.stagerecorder.bundle-105.0.2] startup
# [11.053s] [ext: omni.kit.tool.asset_exporter-4.0.4] startup
# [11.055s] [ext: omni.kit.tool.remove_unused.controller-0.1.4] startup
# [11.057s] [ext: omni.kit.usda_edit-1.1.18] startup
# [11.066s] [ext: omni.kit.widget.live-2.1.11] startup
# [11.068s] [ext: omni.kit.variant.presenter-107.0.0] startup
# [11.073s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [11.074s] [ext: omni.kit.widget.calendar-1.0.9] startup
# [11.076s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [11.076s] [ext: omni.kit.viewport_widgets_manager-1.0.9] startup
# [11.078s] [ext: omni.kit.widget.cache_indicator-3.0.6] startup
# 2025-09-10T08:11:00Z [11,059ms] [Warning] [omni.kit.pipapi.pipapi] extension omni.kit.widget.cache_indicator-3.0.6 has a [python.pipapi] entry, but use_online_index=true is not set. It doesn't do anything and can be removed.
# [11.148s] [ext: omni.kit.property.physx-107.3.18] startup
# [11.173s] [ext: omni.physx.demos-107.3.18] startup
# [11.208s] [ext: omni.kit.widget.extended_searchfield-1.0.31] startup
# [11.220s] [ext: omni.kit.widget.schema_api-1.0.3] startup
# [11.224s] [ext: omni.asset_validator.core-1.1.6] startup
# [11.281s] [ext: omni.scene.optimizer.core-107.3.9] startup
# [11.327s] [ext: omni.usdex.libs-1.2.2] startup
# [11.336s] [ext: omni.physx.vehicle-107.3.18] startup
# [11.682s] [ext: omni.kit.window.commands-0.2.9] startup
# [11.684s] [ext: omni.kit.widget.timeline-107.0.1] startup
# [11.687s] [ext: omni.kit.window.script_editor-2.0.1] startup
# [11.690s] [ext: omni.asset_validator.ui-1.1.6] startup
# [11.700s] [ext: omni.physx.asset_validator-107.3.18] startup
# [11.712s] [ext: omni.kit.converter.common-506.3.1] startup
# [11.714s] [ext: isaacsim.sensors.physx.ui-2.2.12] startup
# [11.716s] [ext: omni.physx.camera-107.3.18] startup
# [11.724s] [ext: omni.physx.cct-107.3.18] startup
# [11.734s] [ext: omni.physx.graph-107.3.18] startup
# [11.750s] [ext: omni.physx.supportui-107.3.18] startup
# [11.764s] [ext: omni.physx.telemetry-107.3.18] startup
# [11.766s] [ext: omni.kit.converter.dgn_core-509.0.1] startup
# [11.821s] [ext: omni.isaac.range_sensor.ui-2.0.5] startup
# 2025-09-10T08:11:01Z [11,803ms] [Warning] [omni.isaac.range_sensor.ui] omni.isaac.range_sensor.ui has been deprecated in favor of isaacsim.sensors.physx.ui. Please update your code accordingly.
# 2025-09-10T08:11:01Z [11,803ms] [Warning] [omni.isaac.range_sensor.ui.menu] omni.isaac.range_sensor.ui.menu has been deprecated in favor of isaacsim.sensors.physx.ui.menu. Please update your code accordingly.
# [11.823s] [ext: omni.kit.converter.hoops_core-508.0.2] startup
# [11.829s] [ext: omni.kit.converter.jt_core-507.0.1] startup
# [11.844s] [ext: omni.kit.window.usd_paths-1.0.8] startup
# [11.846s] [ext: omni.kit.widget.collection-0.3.1] startup
# [11.849s] [ext: omni.physx.bundle-107.3.18] startup
# [11.850s] [ext: omni.kit.converter.dgn-508.0.1] startup
# [12.021s] [ext: isaacsim.replicator.grasping-1.0.9] startup
# [12.329s] [ext: omni.kit.converter.hoops-508.0.1] startup
# [12.334s] [ext: omni.kit.converter.jt-507.0.1] startup
# [12.336s] [ext: omni.kit.quicklayout-1.0.8] startup
# [12.337s] [ext: omni.kit.window.collection-0.3.1] startup
# 2025-09-10T08:11:02Z [12,319ms] [Warning] [omni.kit.window.collection.collection_watch] Get collection from usdrt stage failed: Attach(): incompatible function arguments. The following argument types are supported:
#     1. (stageId: int) -> usdrt.Usd._Usd.Stage
#     2. (fabricId: usdrt.helpers._helpers.FabricId) -> usdrt.Usd._Usd.Stage
#
# Invoked with: -1
# [12.339s] [ext: omni.isaac.physics_inspector-0.1.11] startup
# 2025-09-10T08:11:02Z [12,320ms] [Warning] [omni.isaac.physics_inspector] omni.isaac.physics_inspector has been deprecated.Replaced by Physics Visualization tools
# [12.340s] [ext: isaacsim.util.camera_inspector-1.0.15] startup
# [12.343s] [ext: isaacsim.replicator.grasping.ui-1.0.8] startup
# [12.344s] [ext: isaacsim.asset.validation-1.0.3] startup
# [12.367s] [ext: omni.kit.converter.cad-203.2.1] startup
# [12.367s] [ext: omni.kit.window.stats-0.1.7] startup
# [12.368s] [ext: isaacsim.app.setup-1.4.10] startup
# [12.369s] Isaac Sim Full Version: 5.0.0-rc.45
# [12.370s] Writing Isaac Sim icon file
# [12.370s] [ext: omni.kit.profiler.window-2.3.5] startup
# [12.374s] [ext: isaacsim.exp.full-5.0.0] startup
# Checking to see if RMW can be loaded:
# failed to get symbol 'rmw_init_options_init' due to Environment variable 'AMENT_PREFIX_PATH' is not set or empty, at /workspace/humble_ws/src/rmw_implementation/src/functions.cpp:171, at /workspace/humble_ws/src/rcl/rcl/src/rcl/init_options.c:75
# RMW was not loaded

# %%
kernel.start_loop_soon()
# Out:
# [19.204s] [ext: isaacsim.ros2.bridge-4.9.3] startup
# 2025-09-10T08:11:08Z [19,197ms] [Warning] [isaacsim.ros2.bridge.impl.extension] ROS_DISTRO env var not found, Please source ROS before enabling this extension
# [19.217s] Using backup internal ROS2 humble distro
# [19.223s] To use the internal libraries included with the extension please set the following environment variables to use with FastDDS (default) or CycloneDDS before starting Isaac Sim:
#
# FastDDS (default):
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_fastrtps_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
# OR
#
# CycloneDDS:
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_cyclonedds_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
#
# [19.231s] [ext: isaacsim.ros2.bridge-4.9.3] shutdown
# 2025-09-10T08:11:08Z [19,203ms] [Error] [isaacsim.ros2.bridge.impl.extension] ROS2 Bridge startup failed
# 2025-09-10T08:11:09Z [19,437ms] [Warning] [omni.ext._impl._internal] isaacsim.ros2.bridge-4.9.3 -> <class 'isaacsim.ros2.bridge.impl.samples.ros_moveit_sample.Extension'>: extension object is still alive, something holds a reference on it. References: ["[0]:type: <class 'method'>, id: 140623527307968", "[1]:type: <class 'method'>, id: 140623527306176"]
# 2025-09-10T08:11:09Z [19,677ms] [Warning] [omni.ext._impl._internal] isaacsim.ros2.bridge-4.9.3 -> <class 'isaacsim.ros2.bridge.impl.samples.ros_waypoint_follower_sample.Extension'>: extension object is still alive, something holds a reference on it. References: ["[0]:type: <class 'method'>, id: 140623527303744", "[1]:type: <class 'method'>, id: 140623645868224"]
# 2025-09-10T08:11:09Z [19,717ms] [Warning] [omni.ext._impl._internal] isaacsim.ros2.bridge-4.9.3 -> <class 'isaacsim.ros2.bridge.impl.samples.ros_samples.Extension'>: extension object is still alive, something holds a reference on it. References: ["[0]:type: <class 'method'>, id: 140623574616128", "[1]:type: <class 'method'>, id: 140624686087616", "[2]:type: <class 'method'>, id: 140623902108096", "[3]:type: <class 'method'>, id: 140623527302016", "[4]:type: <class 'method'>, id: 140623527302336", '[*] ...']
# [20.060s] [ext: omni.kit.registry.nucleus-0.0.0] startup
# 2025-09-10T08:11:09Z [20,143ms] [Warning] [usdrt.population.plugin] using high frequency span is disabled
# 2025-09-10T08:11:09Z [20,175ms] [Warning] [omni.fabric.plugin] Warning: attribute viewPickingId not found for bucket id b
#
# 2025-09-10T08:11:10Z [20,276ms] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [carb::dictionary::ISerializer v1.1] (plugin: carb.dictionary.serializer-json.plugin), by client: carb.scenerenderer-rtx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# [20.312s] app ready
# 2025-09-10T08:11:10Z [20,320ms] [Warning] [carb.graphics-vulkan.plugin] Trying to initialize NGX without vkGetInstanceProcAddr and vkGetDeviceProcAddr pointer-to-functions.
# 2025-09-10T08:11:10Z [20,320ms] [Warning] [carb.scenerenderer-rtx.plugin] Failed to create NGX context.
# 2025-09-10T08:11:10Z [20,411ms] [Warning] [rtx.optixdenoising.plugin] Failed to create an Optix 7.5 adaptor on device 0. Temporal denoising will not be available.
# 2025-09-10T08:11:10Z [20,411ms] [Warning] [rtx.optixdenoising.plugin] Failed to initialize OptixDenoiserContext.
# 2025-09-10T08:11:10Z [20,320ms] [Error] [carb.graphics-vulkan.plugin] Could not get NGX parameters block because NGX isn't enabled.
# 2025-09-10T08:11:10Z [20,320ms] [Error] [carb.graphics-vulkan.plugin] Failed to create NGX context.
# 2025-09-10T08:11:10Z [20,412ms] [Error] [rtx.optixdenoising73.plugin] Failed to create an Optix adaptor for device 0
# 2025-09-10T08:11:12Z [22,661ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span is disabled
# 2025-09-10T08:11:12Z [22,661ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span is disabled
# 2025-09-10T08:11:12Z [22,662ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span with attrs is disabled
# 2025-09-10T08:11:12Z [22,693ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span is disabled
# 2025-09-10T08:11:12Z [22,693ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span is disabled
# [22.905s] Isaac Sim Full App is loaded.

# %%
kernel.start_loop_soon()

# %%
import asyncio

loop = asyncio.get_running_loop()
loop
# Out:
# <_UnixSelectorEventLoop running=True closed=False debug=False>

# %%
def f():
    app_framework.update()
    loop.call_soon(f)
loop.call_soon(f)
# Out:
# <Handle f() at /tmp/ipykernel_3537449/3216626267.py:1>
# [288.542s] [ext: isaacsim.ros2.bridge-4.9.3] startup
# 2025-09-10T07:43:05Z [288,537ms] [Warning] [isaacsim.ros2.bridge.impl.extension] ROS_DISTRO env var not found, Please source ROS before enabling this extension
# [288.554s] Using backup internal ROS2 humble distro
# [288.561s] To use the internal libraries included with the extension please set the following environment variables to use with FastDDS (default) or CycloneDDS before starting Isaac Sim:
#
# FastDDS (default):
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_fastrtps_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
# OR
#
# CycloneDDS:
# export ROS_DISTRO=humble
# export RMW_IMPLEMENTATION=rmw_cyclonedds_cpp
# export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/exts/isaacsim.ros2.bridge/humble/lib
#
#
# [288.570s] [ext: isaacsim.ros2.bridge-4.9.3] shutdown
# 2025-09-10T07:43:05Z [288,544ms] [Error] [isaacsim.ros2.bridge.impl.extension] ROS2 Bridge startup failed
# 2025-09-10T07:43:05Z [288,783ms] [Warning] [omni.ext._impl._internal] isaacsim.ros2.bridge-4.9.3 -> <class 'isaacsim.ros2.bridge.impl.samples.ros_moveit_sample.Extension'>: extension object is still alive, something holds a reference on it. References: ["[0]:type: <class 'method'>, id: 140182115256512", "[1]:type: <class 'method'>, id: 140182200646592"]
# 2025-09-10T07:43:05Z [289,007ms] [Warning] [omni.ext._impl._internal] isaacsim.ros2.bridge-4.9.3 -> <class 'isaacsim.ros2.bridge.impl.samples.ros_waypoint_follower_sample.Extension'>: extension object is still alive, something holds a reference on it. References: ["[0]:type: <class 'method'>, id: 140182115258816", "[1]:type: <class 'method'>, id: 140182115257472"]
# 2025-09-10T07:43:05Z [289,051ms] [Warning] [omni.ext._impl._internal] isaacsim.ros2.bridge-4.9.3 -> <class 'isaacsim.ros2.bridge.impl.samples.ros_samples.Extension'>: extension object is still alive, something holds a reference on it. References: ["[0]:type: <class 'method'>, id: 140182124591360", "[1]:type: <class 'method'>, id: 140183263052800", "[2]:type: <class 'method'>, id: 140182124265152", "[3]:type: <class 'method'>, id: 140182115254912", "[4]:type: <class 'method'>, id: 140182115255616", '[*] ...']
# [289.113s] [ext: omni.kit.registry.nucleus-0.0.0] startup
# 2025-09-10T07:43:05Z [289,201ms] [Warning] [usdrt.population.plugin] using high frequency span is disabled
# 2025-09-10T07:43:05Z [289,229ms] [Warning] [omni.fabric.plugin] Warning: attribute viewportHandle not found for bucket id b
#
# 2025-09-10T07:43:05Z [289,332ms] [Warning] [carb] Acquiring non optional plugin interface which is not listed as dependency: [carb::dictionary::ISerializer v1.1] (plugin: carb.dictionary.serializer-json.plugin), by client: carb.scenerenderer-rtx.plugin. Add it to CARB_PLUGIN_IMPL_DEPS() macro of a client.
# [289.357s] app ready
# 2025-09-10T07:43:05Z [289,384ms] [Warning] [carb.graphics-vulkan.plugin] Trying to initialize NGX without vkGetInstanceProcAddr and vkGetDeviceProcAddr pointer-to-functions.
# 2025-09-10T07:43:05Z [289,384ms] [Warning] [carb.scenerenderer-rtx.plugin] Failed to create NGX context.
# 2025-09-10T07:43:05Z [289,473ms] [Warning] [rtx.optixdenoising.plugin] Failed to create an Optix 7.5 adaptor on device 0. Temporal denoising will not be available.
# 2025-09-10T07:43:05Z [289,473ms] [Warning] [rtx.optixdenoising.plugin] Failed to initialize OptixDenoiserContext.
# 2025-09-10T07:43:05Z [289,384ms] [Error] [carb.graphics-vulkan.plugin] Could not get NGX parameters block because NGX isn't enabled.
# 2025-09-10T07:43:05Z [289,384ms] [Error] [carb.graphics-vulkan.plugin] Failed to create NGX context.
# 2025-09-10T07:43:05Z [289,474ms] [Error] [rtx.optixdenoising73.plugin] Failed to create an Optix adaptor for device 0
# 2025-09-10T07:43:08Z [291,726ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span is disabled
# 2025-09-10T07:43:08Z [291,726ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span is disabled
# 2025-09-10T07:43:08Z [291,727ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span with attrs is disabled
# 2025-09-10T07:43:08Z [291,757ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span is disabled
# 2025-09-10T07:43:08Z [291,757ms] [Warning] [usdrt.hydra.fabric_scene_delegate.plugin] using high frequency span is disabled
# [291.985s] Isaac Sim Full App is loaded.

# %%
app_framework

# %%
# should_run = True

# async def todo():
#     while should_run:
#         app_framework.update()

# import asyncio
# asyncio.create_task(todo())

# %%
import omni

omni.usd.get_context().get_stage()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 import omni
# ----> 3 omni.usd.get_context().get_stage()
#
# AttributeError: module 'omni' has no attribute 'usd'
