# %%
from robotodo.engines.isaac._kernel import configure_default_kernel, get_default_kernel
configure_default_kernel(
    extra_argv=[
        "--reset-user",

        "--/app/enableStdoutOutput=true",
        "--/log/file=/tmp/todo-isaacsim-min-v1.log",

        # TODO
        "--/persistent/app/stage/upAxis='Z'",

        # "--/persistent/renderer/startupMessageDisplayed=true"

        #"--enable", "omni.physx.asset_validator",

        # "--enable", "omni.usd_resolver",

        "--enable", "omni.physics.physx",
        "--enable", "omni.physics.stageupdate",
        "--enable", "omni.physx.tensors",

        # "--enable", "omni.syntheticdata",
        "--/app/fabricDefaultStageFrameHistoryCount=3" # needed for omni.syntheticdata TODO105 still true?

        "--enable", "omni.replicator.core",

        "--enable", "omni.kit.viewport.window",
        # "--enable", "omni.kit.manipulator.camera",
        # "--enable", "omni.kit.manipulator.prim",
        # "--enable", "omni.kit.manipulator.selection",
        # "--enable", "omni.kit.window.stage",
        # "--enable", "omni.kit.window.toolbar",
        # "--enable", "omni.kit.window.property",
        "--enable", "omni.kit.quicklayout",

        # "--enable", "isaacsim.exp.full",

    ], 
    kit_path="isaacsim.exp.todo.full.copy.kit",
    # kit_path=None,
    # kit_path="isaacsim.exp.base.kit",
)

# %%
# get_default_kernel().enable_extension("omni.kit.tool.asset_importer")

# %%
from robotodo.engines.isaac.scene import Scene

scene = Scene.load(
    "https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Environments/Grid/default_environment.usd"
)
# TODO
# scene = Scene.create()
# Out:
# [Warning] [simulation_app] Interactive python shell detected but ISAAC_JUPYTER_KERNEL was not set. Problems with asyncio may occur
# [Warning] [simulation_app] Please use Isaac Sim Python 3 kernel instead of the default Python 3 Kernel
# [0.152s] [ext: omni.kit.async_engine-0.0.3] startup
# [0.333s] [ext: omni.metrics.core-0.0.3] startup
# [0.333s] [ext: omni.client.lib-1.1.0] startup
# [0.349s] [ext: omni.blobkey-1.1.2] startup
# [0.349s] [ext: omni.stats-1.0.1] startup
# [0.350s] [ext: omni.datastore-0.0.0] startup
# [0.354s] [ext: omni.client-1.3.0] startup
# [0.410s] [ext: omni.ujitso.default-1.0.0] startup
# [0.411s] [ext: omni.hsscclient-1.1.2] startup
# [0.415s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.417s] [ext: omni.assets.plugins-0.0.0] startup
# [0.418s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.424s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.432s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 535.247.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3090          | Yes: 0 |     | 24576   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2204      | 3b061d17.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 12 (bookworm) debian, Version: 12.00.0, Kernel: 6.1.0-39-amd64
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101007 (1.21.1.7)
# | Processor: 12th Gen Intel(R) Core(TM) i5-12400F
# | Cores: 6 | Logical Cores: 12
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 64139 | Free Memory: 28023
# | Total Page/Swap (MB): 16383 | Free Page/Swap: 15018
# |---------------------------------------------------------------------------------------------|
# [0.954s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.955s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.956s] [ext: omni.materialx.libs-1.0.7] startup
# [0.962s] [ext: omni.pip.compute-1.6.2] startup
# [0.963s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [0.964s] [ext: omni.kit.test-2.0.1] startup
# [0.990s] [ext: omni.kit.telemetry-0.5.2] startup
# [1.010s] [ext: omni.usd.config-1.0.6] startup
# [1.014s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.015s] [ext: omni.usd.libs-1.0.1] startup
# [1.095s] [ext: omni.mdl-56.0.3] startup
# [1.124s] [ext: omni.iray.libs-0.0.0] startup
# [1.128s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [1.130s] [ext: omni.kit.usd.mdl-1.1.4] startup
# [1.210s] [ext: omni.appwindow-1.1.10] startup
# [1.900s] [ext: omni.kit.renderer.core-1.1.0] startup
# [5.996s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [5.999s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [6.079s] [ext: omni.ui-2.26.18] startup
# [6.088s] [ext: omni.kit.mainwindow-1.0.3] startup
# [6.089s] [ext: carb.audio-0.1.0] startup
# [6.092s] [ext: omni.uiaudio-1.0.0] startup
# [6.093s] [ext: omni.kit.uiapp-0.0.0] startup
# [6.093s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [6.094s] [ext: omni.usd.schema.audio-0.0.0] startup
# [6.097s] [ext: omni.usd_resolver-1.0.0] startup
# [6.101s] [ext: omni.usd.core-1.5.3] startup
# [6.104s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [6.125s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [6.125s] [ext: omni.usd.schema.physx-107.3.18] startup
# [6.155s] [ext: omni.usd.schema.anim-0.0.0] startup
# [6.173s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [6.176s] [ext: omni.anim.graph.schema-107.3.0] startup
# [6.181s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [6.183s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [6.187s] [ext: omni.resourcemonitor-107.0.1] startup
# [6.189s] [ext: omni.activity.core-1.0.3] startup
# [6.190s] [ext: omni.timeline-1.0.14] startup
# [6.192s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [6.193s] [ext: omni.graph.exec-0.9.6] startup
# [6.194s] [ext: omni.kit.actions.core-1.0.0] startup
# [6.196s] [ext: usdrt.scenegraph-7.6.1] startup
# [6.272s] [ext: omni.kit.usd_undo-0.1.8] startup
# [6.273s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [6.274s] [ext: omni.kit.exec.core-0.13.4] startup
# [6.276s] [ext: omni.kit.commands-1.4.10] startup
# [6.279s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [6.285s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [6.289s] [ext: omni.usd-1.13.10] startup
# [6.310s] [ext: omni.kit.asset_converter-5.0.15] startup
# [6.323s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [6.329s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [6.333s] [ext: omni.inspect-1.0.2] startup
# [6.334s] [ext: omni.kit.notification_manager-1.0.10] startup
# [6.357s] [ext: omni.graph.core-2.184.3] startup
# [6.359s] [ext: isaacsim.core.deprecation_manager-0.2.7] startup
# [6.360s] [ext: omni.pip.cloud-1.3.6] startup
# [6.363s] [ext: omni.anim.navigation.schema-107.3.0] startup
# [6.366s] [ext: omni.usd.schema.flow-107.1.1] startup
# [6.366s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [6.367s] [ext: isaacsim.robot.schema-3.5.1] startup
# [6.374s] [ext: omni.usd.schema.isaac-3.0.5] startup
# [6.374s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [6.375s] [ext: omni.kit.menu.core-1.1.2] startup
# [6.376s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [6.377s] [ext: omni.kit.widget.filebrowser-2.12.2] startup
# [6.381s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [6.382s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [6.383s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [6.386s] [ext: omni.ui.scene-1.11.4] startup
# [6.390s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [6.391s] [ext: omni.kit.clipboard-1.0.5] startup
# [6.392s] [ext: omni.kit.window.filepicker-2.13.3] startup
# [6.404s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [6.406s] [ext: omni.kit.usd.layers-2.2.10] startup
# [6.417s] [ext: omni.kit.menu.utils-2.0.3] startup
# [6.424s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [6.424s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [6.426s] [ext: omni.kit.menu.create-2.0.1] startup
# [6.428s] [ext: isaacsim.core.version-2.0.6] startup
# [6.428s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [6.429s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [6.430s] [ext: omni.kvdb-107.3.18] startup
# [6.432s] [ext: omni.usdphysics-107.3.18] startup
# [6.434s] [ext: omni.physx.foundation-107.3.18] startup
# [6.435s] [ext: omni.localcache-107.3.18] startup
# [6.437s] [ext: omni.convexdecomposition-107.3.18] startup
# [6.439s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [6.440s] [ext: omni.physx.cooking-107.3.18] startup
# [6.443s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [6.443s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [6.444s] [ext: omni.kit.widget.stage_icons-1.0.8] startup
# [6.444s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [6.445s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [6.447s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [6.448s] [ext: omni.kit.widget.filter-1.1.4] startup
# [6.448s] [ext: omni.kit.context_menu-1.8.6] startup
# [6.450s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [6.451s] [ext: omni.kit.window.file-2.0.5] startup
# [6.454s] [ext: omni.kit.widget.stage-3.1.4] startup
# [6.464s] [ext: omni.kit.window.property-1.12.1] startup
# [6.468s] [ext: omni.kit.window.content_browser-3.1.1] startup
# [6.481s] [ext: omni.kit.window.stage-2.6.1] startup
# [6.485s] [ext: omni.kit.property.usd-4.5.11] startup
# [6.498s] [ext: omni.graph.image.core-0.6.1] startup
# [6.499s] [ext: omni.physx-107.3.18] startup
# [6.509s] [ext: omni.kit.scripting-107.3.1] startup
# [6.513s] [ext: omni.graph.tools-1.79.2] startup
# [6.535s] [ext: isaacsim.storage.native-1.2.8] startup
# [6.536s] [ext: omni.kit.widget.graph-2.0.0] startup
# [6.543s] [ext: omni.graph.image.nodes-1.3.1] startup
# [6.547s] [ext: isaacsim.replicator.behavior-1.1.14] startup
# [6.548s] [ext: omni.kit.graph.delegate.default-1.2.3] startup
# [6.548s] [ext: omni.index.libs-380600.5717.0] startup
# [6.548s] [ext: omni.kit.widget.settings-1.2.3] startup
# [6.550s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [6.551s] [ext: omni.ujitso.client-0.0.0] startup
# [6.552s] [ext: omni.index-1.0.1] startup
# [6.552s] [ext: omni.kit.window.preferences-1.8.0] startup
# [6.556s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [6.557s] [ext: omni.volume-0.5.2] startup
# [6.560s] [ext: omni.graph-1.141.2] startup
# [6.603s] [ext: omni.hydra.rtx-1.0.0] startup
# [6.635s] [ext: omni.kit.viewport.menubar.core-107.1.5] startup
# [6.694s] [ext: omni.graph.nodes_core-1.1.0] startup
# [6.699s] [ext: omni.kit.hydra_texture-1.4.5] startup
# [6.704s] [ext: omni.kit.raycast.query-1.1.0] startup
# [6.709s] [ext: omni.kit.material.library-2.0.7] startup
# [6.716s] [ext: omni.physics-107.3.18] startup
# [6.720s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [6.723s] [ext: omni.physics.physx-107.3.18] startup
# [6.725s] [ext: omni.kit.numpy.common-0.1.2] startup
# [6.727s] [ext: omni.physics.tensors-107.3.18] startup
# [6.733s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# [6.737s] [ext: omni.physics.stageupdate-107.3.18] startup
# [6.739s] [ext: omni.warp.core-1.8.1] startup
# [6.974s] [ext: omni.usd.metrics.assembler.physics-107.3.18] startup
# [6.976s] [ext: omni.isaac.dynamic_control-2.0.7] startup
# [6.982s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [6.986s] [ext: omni.physx.tensors-107.3.18] startup
# [6.990s] [ext: isaacsim.core.utils-3.4.5] startup
# [6.993s] [ext: omni.kit.stage_templates-2.0.0] startup
# [6.997s] [ext: isaacsim.test.docstring-1.1.0] startup
# [7.000s] [ext: isaacsim.core.simulation_manager-1.3.2] startup
# [8.306s] [ext: isaacsim.core.experimental.utils-0.2.0] startup
# [8.309s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [8.314s] [ext: isaacsim.core.experimental.prims-0.6.2] startup
# [8.337s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [8.343s] [ext: omni.kit.viewport.legacy_gizmos-1.0.18] startup
# [8.346s] [ext: omni.graph.action_core-1.1.7] startup
# [8.347s] [ext: omni.kit.viewport.window-107.0.12] startup
# [8.366s] [ext: isaacsim.core.experimental.objects-0.2.4] startup
# [8.369s] [ext: omni.graph.action_nodes_core-1.2.0] startup
# [8.373s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [8.375s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [8.376s] [ext: omni.graph.action_nodes-1.51.0] startup
# [8.379s] [ext: omni.kit.menu.stage-1.2.7] startup
# [8.381s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [8.398s] [ext: omni.graph.action-1.130.0] startup
# [8.402s] [ext: omni.kit.widget.zoombar-1.0.7] startup
# [8.407s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [8.409s] [ext: omni.kit.usd.collect-2.4.5] startup
# [8.415s] [ext: omni.kit.browser.core-2.3.16] startup
# [8.516s] [ext: omni.kit.tool.collect-2.2.18] startup
# [8.519s] [ext: omni.kit.browser.folder.core-1.10.10] startup
# [8.524s] [ext: omni.ui_query-1.1.8] startup
# [8.525s] [ext: omni.kit.usdz_export-1.0.9] startup
# [8.528s] [ext: omni.kit.window.extensions-1.4.26] startup
# [8.535s] [ext: omni.kit.ui_test-1.3.6] startup
# [8.538s] [ext: omni.kit.tool.asset_importer-5.0.4] startup
# [8.542s] [ext: isaacsim.gui.components-1.1.9] startup
# [8.548s] [ext: isaacsim.examples.browser-0.1.12] startup
# [8.553s] [ext: isaacsim.asset.importer.urdf-2.4.19] startup
# [8.614s] [ext: omni.syntheticdata-0.6.13] startup
# [8.644s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [8.649s] [ext: omni.graph.nodes-1.171.0] startup
# [8.661s] [ext: isaacsim.simulation_app-2.9.2] startup
# [8.662s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [8.665s] [ext: omni.graph.ui_nodes-1.50.8] startup
# [8.670s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [8.673s] [ext: omni.videoencoding-0.1.2] startup
# [8.676s] [ext: isaacsim.core.prims-0.5.1] startup
# [8.697s] [ext: omni.warp-1.8.1] startup
# [8.706s] [ext: omni.isaac.kit-2.0.6] startup
# [8.711s] [ext: omni.kit.window.material_graph-1.9.1] startup
# [8.736s] [ext: omni.graph.scriptnode-1.50.0] startup
# [8.741s] [ext: isaacsim.core.api-4.6.10] startup
# [8.805s] [ext: omni.replicator.core-1.12.23] startup
# Warp 1.8.1 initialized:
#    CUDA Toolkit 12.8, Driver 12.2
#    Devices:
#      "cpu"      : "CPU"
#      "cuda:0"   : "NVIDIA GeForce RTX 3090" (24 GiB, sm_86, mempool enabled)
#    Kernel cache:
#      /home/sysadmin/.cache/warp/1.8.1
# [8.938s] [ext: isaacsim.robot_motion.lula-4.0.8] startup
# [8.950s] [ext: isaacsim.robot.surface_gripper-3.2.6] startup
# [8.955s] [ext: isaacsim.core.nodes-3.2.16] startup
# [8.969s] [ext: isaacsim.robot_motion.motion_generation-8.0.25] startup
# [8.988s] [ext: isaacsim.robot.manipulators-3.3.5] startup
# [9.001s] [ext: omni.isaac.core_nodes-2.0.6] startup
# [9.009s] [ext: isaacsim.robot.manipulators.examples-1.0.17] startup
# [9.016s] [ext: omni.kit.property.audio-1.0.16] startup
# [9.024s] [ext: isaacsim.cortex.framework-1.0.12] startup
# [9.031s] [ext: omni.kit.property.camera-1.0.10] startup
# [9.042s] [ext: omni.hydra.scene_api-0.1.2] startup
# [9.051s] [ext: omni.kit.property.geometry-2.0.4] startup
# [9.066s] [ext: omni.kit.property.light-1.0.12] startup
# [9.085s] [ext: isaacsim.cortex.behaviors-2.0.12] startup
# [9.089s] [ext: omni.kit.property.material-1.11.9] startup
# [9.115s] [ext: omni.kit.property.transform-1.5.12] startup
# [9.124s] [ext: omni.kit.property.render-1.2.1] startup
# [9.127s] [ext: omni.isaac.cortex-1.0.5] startup
# [9.131s] [ext: omni.isaac.cortex.sample_behaviors-2.0.5] startup
# [9.134s] [ext: omni.anim.curve.core-1.3.1] startup
# [9.154s] [ext: isaacsim.robot_motion.lula_test_widget-1.0.12] startup
# [9.159s] [ext: omni.kit.property.bundle-1.4.1] startup
# [9.164s] [ext: omni.isaac.lula-4.0.6] startup
# [9.167s] [ext: omni.isaac.manipulators-3.0.7] startup
# [9.176s] [ext: omni.kit.viewport.menubar.lighting-107.3.1] startup
# [9.186s] [ext: omni.isaac.lula_test_widget-1.0.6] startup
# [9.187s] [ext: isaacsim.core.throttling-2.1.10] startup
# [9.192s] [ext: isaacsim.asset.importer.mjcf-2.5.8] startup
# [9.209s] [ext: omni.kit.selection-0.1.6] startup
# [9.233s] [ext: omni.kit.widget.toolbar-2.0.1] startup
# [9.454s] [ext: omni.kit.manipulator.transform-107.0.0] startup
# [9.514s] [ext: isaacsim.gui.menu-2.3.17] startup
# Warp DeprecationWarning: The `warp.sim` module is deprecated and will be removed in v1.10. Please transition to using the forthcoming Newton library instead.
# [10.286s] [ext: isaacsim.asset.browser-1.3.19] startup
# [10.294s] [ext: omni.kit.manipulator.tool.snap-1.5.13] startup
# [10.301s] [ext: omni.kit.manipulator.selector-1.1.3] startup
# [10.303s] [ext: omni.isaac.menu-1.0.6] startup
# [10.304s] [ext: omni.isaac.motion_generation-8.0.7] startup
# [10.309s] [ext: omni.isaac.asset_browser-1.0.6] startup
# [10.311s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [10.316s] [ext: omni.isaac.nucleus-1.0.6] startup
# [10.318s] [ext: omni.fabric.commands-1.1.6] startup
# [10.322s] [ext: omni.kit.manipulator.prim.core-107.0.8] startup
# [10.329s] [ext: isaacsim.robot.wheeled_robots-4.0.23] startup
# [10.335s] [ext: omni.isaac.utils-2.0.6] startup
# [10.339s] [ext: omni.isaac.version-2.0.7] startup
# [10.342s] [ext: omni.isaac.wheeled_robots-3.0.7] startup
# [10.348s] [ext: omni.sensors.nv.common-2.7.0-coreapi] startup
# [10.363s] [ext: isaacsim.app.about-2.0.11] startup
# [10.373s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [10.378s] [ext: isaacsim.sensors.physics-0.3.27] startup
# [10.383s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [10.387s] [ext: omni.sensors.net-0.4.0-coreapi] startup
# [10.391s] [ext: omni.sensors.nv.materials-1.6.0-coreapi] startup
# [10.398s] [ext: omni.isaac.window.about-2.0.7] startup
# [10.401s] [ext: omni.kit.manipulator.camera-106.0.4] startup
# [10.405s] [ext: isaacsim.robot.policy.examples-4.1.11] startup
# [10.406s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [10.407s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [10.411s] [ext: omni.sensors.nv.ids-1.5.0-coreapi] startup
# [10.413s] [ext: omni.sensors.nv.wpm-2.5.0-coreapi] startup
# [10.415s] [ext: omni.sensors.nv.lidar-2.7.0-coreapi] startup
# [10.420s] [ext: omni.isaac.quadruped-3.0.7] startup
# [10.421s] [ext: omni.isaac.assets_check-0.3.13] startup
# [10.423s] [ext: isaacsim.gui.content_browser-0.1.9] startup
# [10.428s] [ext: isaacsim.util.debug_draw-3.1.0] startup
# [10.433s] [ext: omni.sensors.nv.radar-2.8.0-coreapi] startup
# [10.436s] [ext: omni.isaac.franka-1.0.7] startup
# [10.437s] [ext: isaacsim.gui.property-1.1.3] startup
# [10.441s] [ext: isaacsim.sensors.physx-2.2.27] startup
# [10.446s] [ext: isaacsim.sensors.camera-1.3.1] startup
# [10.454s] [ext: isaacsim.sensors.rtx-15.5.0] startup
# [10.466s] [ext: isaacsim.core.cloner-1.4.9] startup
# [10.471s] [ext: omni.kit.property.isaac-1.0.6] startup
# [10.618s] [ext: omni.isaac.range_sensor-4.0.6] startup
# [10.619s] [ext: omni.kit.viewport.menubar.camera-107.0.3] startup
# [10.627s] [ext: omni.isaac.sensor-13.0.7] startup
# [10.629s] [ext: omni.isaac.cloner-1.0.7] startup
# [10.632s] [ext: omni.kit.viewport.menubar.render-107.0.9] startup
# [10.643s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [10.648s] [ext: isaacsim.replicator.writers-1.0.15] startup
# [10.663s] [ext: omni.kit.window.console-1.1.4] startup
# [10.671s] [ext: omni.kit.window.status_bar-0.1.8] startup
# [10.679s] [ext: omni.kit.viewport.actions-107.0.2] startup
# [10.684s] [ext: isaacsim.replicator.domain_randomization-1.0.16] startup
# [10.687s] [ext: isaacsim.replicator.examples-1.1.31] startup
# [10.690s] [ext: omni.ocio-0.1.1] startup
# [10.694s] [ext: omni.rtx.window.settings-0.6.19] startup
# [10.706s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [10.715s] [ext: omni.kit.window.toolbar-2.0.0] startup
# [10.724s] [ext: omni.replicator.isaac-2.0.8] startup
# [10.725s] [ext: omni.replicator.replicator_yaml-2.0.11] startup
# [10.744s] [ext: omni.rtx.settings.core-0.6.5] startup
# [10.752s] [ext: omni.usd.metrics.assembler.ui-107.3.1] startup
# [10.765s] [ext: omni.isaac.surface_gripper-2.0.6] startup
# [10.768s] [ext: semantics.schema.editor-2.0.2] startup
# [10.773s] [ext: omni.kit.ui.actions-1.0.5] startup
# [10.775s] [ext: semantics.schema.property-2.0.1] startup
# [10.777s] [ext: omni.isaac.universal_robots-1.0.6] startup
# [10.778s] [ext: omni.isaac.core-4.0.7] startup
# [10.783s] [ext: isaacsim.gui.sensors.icon-2.0.3] startup
# [10.795s] [ext: isaacsim.core.experimental.materials-0.3.0] startup
# [10.800s] [ext: omni.kit.menu.common-2.0.0] startup
# [10.803s] [ext: isaacsim.exp.base-5.0.0] startup
# [10.804s] [ext: omni.kit.quicklayout-1.0.8] startup
# [10.805s] [ext: isaacsim.exp.todo.full.copy-5.0.0] startup
# 2025-12-02T05:19:31Z [11,263ms] [Error] [carb.graphics-vulkan.plugin] Could not get NGX parameters block because NGX isn't enabled.
# 2025-12-02T05:19:31Z [11,263ms] [Error] [carb.graphics-vulkan.plugin] Failed to create NGX context.
# 2025-12-02T05:19:31Z [11,370ms] [Error] [rtx.optixdenoising73.plugin] Failed to create an Optix adaptor for device 0
# [11.362s] app ready
# set 0: [SimpleListItem]: 1.0: 1.0, <omni.ui._ui.SimpleFloatModel object at 0x7feaf0b3c6b0>, [1.0, 0.6000000238418579, 0.0, 1.0]
# set 1: [SimpleListItem]: 0.6: 0.6, <omni.ui._ui.SimpleFloatModel object at 0x7feaf0b3ccb0>, [1.0, 0.6000000238418579, 0.0, 1.0]
# set 2: [SimpleListItem]: 0.0: 0.0, <omni.ui._ui.SimpleFloatModel object at 0x7feaf0b3c9b0>, [1.0, 0.6000000238418579, 0.0, 1.0]
# set 3: [SimpleListItem]: 1.0: 1.0, <omni.ui._ui.SimpleFloatModel object at 0x7feaf0b3cef0>, [1.0, 0.6000000238418579, 0.0, 1.0]
# [omni.kit.registry.nucleus] [tid: 140663197611264] downloading: 'https://d4i3qtqj3r0z5.cloudfront.net/isaacsim.core.throttling-2.1.10%2B107.3.1.zip' -> '/tmp/tmp_82qc3km/isaacsim.core.throttling-2.1.10+107.3.1.zip'...
# [omni.kit.registry.nucleus] [tid: 140663197611264] unpacking: /tmp/tmp_82qc3km/isaacsim.core.throttling-2.1.10+107.3.1.zip -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.core.throttling-2.1.10+107.3.1
# [omni.kit.registry.nucleus] [tid: 140663197611264] creating a link: /home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Base/5.0/exts/3/isaacsim.core.throttling-2.1.10+107.3.1 -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.core.throttling-2.1.10+107.3.1
# [omni.kit.registry.nucleus] [tid: 140663197611264] downloading: 'https://d4i3qtqj3r0z5.cloudfront.net/isaacsim.gui.content_browser-0.1.9%2B107.3.1.zip' -> '/tmp/tmpdee0vkan/isaacsim.gui.content_browser-0.1.9+107.3.1.zip'...
# [omni.kit.registry.nucleus] [tid: 140663197611264] unpacking: /tmp/tmpdee0vkan/isaacsim.gui.content_browser-0.1.9+107.3.1.zip -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.gui.content_browser-0.1.9+107.3.1
# [omni.kit.registry.nucleus] [tid: 140663197611264] creating a link: /home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Base/5.0/exts/3/isaacsim.gui.content_browser-0.1.9+107.3.1 -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.gui.content_browser-0.1.9+107.3.1
# [omni.kit.registry.nucleus] [tid: 140663197611264] creating a link: /home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Base/5.0/exts/3/isaacsim.gui.components-1.1.9+107.3.1 -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.gui.components-1.1.9+107.3.1
# [omni.kit.registry.nucleus] [tid: 140663197611264] downloading: 'https://d4i3qtqj3r0z5.cloudfront.net/isaacsim.examples.browser-0.1.12.zip' -> '/tmp/tmp5ttaoue7/isaacsim.examples.browser-0.1.12.zip'...
# [omni.kit.registry.nucleus] [tid: 140663197611264] unpacking: /tmp/tmp5ttaoue7/isaacsim.examples.browser-0.1.12.zip -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.examples.browser-0.1.12
# [omni.kit.registry.nucleus] [tid: 140663197611264] creating a link: /home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Base/5.0/exts/3/isaacsim.examples.browser-0.1.12 -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.examples.browser-0.1.12
# [omni.kit.registry.nucleus] [tid: 140663197611264] creating a link: /home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Base/5.0/exts/3/isaacsim.asset.importer.urdf-2.4.19+107.3.1.lx64.r.cp311 -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.asset.importer.urdf-2.4.19+107.3.1.lx64.r.cp311
# [omni.kit.registry.nucleus] [tid: 140663197611264] downloading: 'https://d4i3qtqj3r0z5.cloudfront.net/isaacsim.core.experimental.utils-0.2.0%2B107.3.1.zip' -> '/tmp/tmp_kqjh0gn/isaacsim.core.experimental.utils-0.2.0+107.3.1.zip'...
# [omni.kit.registry.nucleus] [tid: 140663197611264] unpacking: /tmp/tmp_kqjh0gn/isaacsim.core.experimental.utils-0.2.0+107.3.1.zip -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.core.experimental.utils-0.2.0+107.3.1
# [omni.kit.registry.nucleus] [tid: 140663197611264] creating a link: /home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Base/5.0/exts/3/isaacsim.core.experimental.utils-0.2.0+107.3.1 -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.core.experimental.utils-0.2.0+107.3.1
# [omni.kit.registry.nucleus] [tid: 140663197611264] downloading: 'https://d4i3qtqj3r0z5.cloudfront.net/isaacsim.asset.importer.mjcf-2.5.8%2B107.3.1.lx64.r.cp311.zip' -> '/tmp/tmpu4hzmb55/isaacsim.asset.importer.mjcf-2.5.8+107.3.1.lx64.r.cp311.zip'...
# [omni.kit.registry.nucleus] [tid: 140663197611264] unpacking: /tmp/tmpu4hzmb55/isaacsim.asset.importer.mjcf-2.5.8+107.3.1.lx64.r.cp311.zip -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.asset.importer.mjcf-2.5.8+107.3.1.lx64.r.cp311
# [omni.kit.registry.nucleus] [tid: 140663197611264] creating a link: /home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/omni/data/Kit/Isaac-Sim Base/5.0/exts/3/isaacsim.asset.importer.mjcf-2.5.8+107.3.1.lx64.r.cp311 -> /home/sysadmin/.local/share/ov/data/exts/v2/isaacsim.asset.importer.mjcf-2.5.8+107.3.1.lx64.r.cp311

# %%
s = scene._kernel.get_settings()
s.get_settings_dictionary().get_dict()["persistent"]["app"]["stage"]
# Out:
# {'upAxis': 'Z',
#  'timeCodeRange': (0, 1000000),
#  'materialStrength': 'weakerThanDescendants',
#  'movePrimInPlace': 1,
#  'instanceableOnCreatingReference': False,
#  'interpolationType': 'Linear',
#  'timeCodesPerSecond': 60.0,
#  'defaultPrimName': 'World',
#  'dragDropImport': 'payload',
#  'nestedGprimsAuthoring': False,
#  'unicodeNormalizationMethod': 'NFC'}

# %%
from robotodo.engines.isaac.articulation import Articulation

panda = Articulation.load(
    "/TODOPanda0",
    "/home/sysadmin/lab/robotodo/__todo__/todo-202510xx-misc/todo-curobo-sample-configs/franka/franka_description/franka_panda.urdf",
    scene=scene,
)
# Out:
# /home/sysadmin/lab/robotodo/packages/robotodo/engines/isaac/_utils/usd.py:154: UserWarning: TODO: Usd.Stage.Open(rootLayer=Sdf.Find('https://omniverse-content-production.s3-us-west-2.amazonaws.com/Assets/Isaac/5.0/Isaac/Environments/Grid/default_environment.usd'), sessionLayer=Sdf.Find('anon:0x2c847b80:default_environment-session.usda'), pathResolverContext=<invalid repr>) Sdf.Find('anon:0x36151a90:.usda')
#   warnings.warn(f"TODO: {stage} {sdf_layer}")
# [1352.500s] [ext: isaacsim.exp.todo.full.copy-5.0.0] shutdown
# [1352.502s] [ext: isaacsim.exp.base-5.0.0] shutdown
# [1352.502s] [ext: omni.isaac.window.about-2.0.7] shutdown
# [1352.788s] [ext: isaacsim.app.about-2.0.11] shutdown
# [1353.130s] [ext: omni.replicator.isaac-2.0.8] shutdown
# [1353.396s] [ext: isaacsim.replicator.examples-1.1.31] shutdown
# [1353.891s] [ext: isaacsim.replicator.writers-1.0.15] shutdown
# [1354.294s] [ext: omni.isaac.quadruped-3.0.7] shutdown
# [1354.568s] [ext: isaacsim.robot.policy.examples-4.1.11] shutdown
# [1354.852s] [ext: omni.isaac.cortex.sample_behaviors-2.0.5] shutdown
# [1355.118s] [ext: isaacsim.cortex.behaviors-2.0.12] shutdown
# [1355.430s] [ext: omni.isaac.cortex-1.0.5] shutdown
# [1355.910s] [ext: isaacsim.cortex.framework-1.0.12] shutdown
# [1356.283s] [ext: omni.isaac.franka-1.0.7] shutdown
# [1356.555s] [ext: omni.isaac.universal_robots-1.0.6] shutdown
# [1356.823s] [ext: isaacsim.robot.manipulators.examples-1.0.17] shutdown
# [1357.095s] [ext: omni.isaac.manipulators-3.0.7] shutdown
# [1357.623s] [ext: isaacsim.robot.manipulators-3.3.5] shutdown
# [1357.958s] [ext: omni.isaac.surface_gripper-2.0.6] shutdown
# [1358.650s] [ext: isaacsim.robot.surface_gripper-3.2.6] shutdown
# [1359.074s] [ext: omni.isaac.wheeled_robots-3.0.7] shutdown
# [1359.340s] [ext: isaacsim.robot.wheeled_robots-4.0.23] shutdown
# [1359.654s] [ext: omni.isaac.sensor-13.0.7] shutdown
# [1360.158s] [ext: isaacsim.sensors.camera-1.3.1] shutdown
# [1360.640s] [ext: isaacsim.sensors.rtx-15.5.0] shutdown
# [1361.321s] [ext: isaacsim.sensors.physics-0.3.27] shutdown
# [1361.780s] [ext: omni.isaac.core_nodes-2.0.6] shutdown
# [1362.047s] [ext: isaacsim.core.nodes-3.2.16] shutdown
# [1362.515s] [ext: omni.isaac.menu-1.0.6] shutdown
# [1362.818s] [ext: isaacsim.gui.menu-2.3.17] shutdown
# [1364.262s] [ext: isaacsim.replicator.domain_randomization-1.0.16] shutdown
# [1364.521s] [ext: omni.isaac.lula_test_widget-1.0.6] shutdown
# [1364.831s] [ext: isaacsim.robot_motion.lula_test_widget-1.0.12] shutdown
# [1365.505s] [ext: omni.isaac.motion_generation-8.0.7] shutdown
# [1365.774s] [ext: isaacsim.robot_motion.motion_generation-8.0.25] shutdown
# [1366.042s] [ext: omni.isaac.range_sensor-4.0.6] shutdown
# [1366.296s] [ext: isaacsim.sensors.physx-2.2.27] shutdown
# [1366.554s] [ext: omni.isaac.assets_check-0.3.13] shutdown
# [1366.847s] [ext: omni.isaac.core-4.0.7] shutdown
# [1367.155s] [ext: isaacsim.core.api-4.6.10] shutdown
# [1367.440s] [ext: omni.isaac.asset_browser-1.0.6] shutdown
# [1367.694s] [ext: isaacsim.asset.browser-1.3.19] shutdown
# [1368.002s] [ext: isaacsim.core.experimental.materials-0.3.0] shutdown
# [1368.239s] [ext: isaacsim.core.experimental.objects-0.2.4] shutdown
# [1368.477s] [ext: isaacsim.core.experimental.prims-0.6.2] shutdown
# [1368.714s] [ext: isaacsim.core.prims-0.5.1] shutdown
# [1368.957s] [ext: omni.isaac.cloner-1.0.7] shutdown
# [1369.209s] [ext: isaacsim.core.cloner-1.4.9] shutdown
# [1369.450s] [ext: isaacsim.core.simulation_manager-1.3.2] shutdown
# [1369.711s] [ext: isaacsim.gui.sensors.icon-2.0.3] shutdown
# [1369.965s] [ext: omni.isaac.utils-2.0.6] shutdown
# [1370.227s] [ext: isaacsim.core.utils-3.4.5] shutdown
# [1370.467s] [ext: isaacsim.replicator.behavior-1.1.14] shutdown
# [1370.718s] [ext: omni.isaac.nucleus-1.0.6] shutdown
# [1370.962s] [ext: isaacsim.storage.native-1.2.8] shutdown
# [1371.202s] [ext: omni.isaac.version-2.0.7] shutdown
# [1371.455s] [ext: isaacsim.core.version-2.0.6] shutdown
# [1371.890s] Failed to solve some dependencies locally, syncing with extension registry...
# [1371.904s] [ext: omni.kit.registry.nucleus-0.0.0] startup
# 2025-12-02T05:42:14Z [1,374,756ms] [Error] [omni.ext.plugin] Failed to resolve extension dependencies. Failure hints:
# 	Can't find extension to satisfy dependency: 'isaacsim.exp.base' = { version='=5.0.0' }
#  Available versions:
# 	 - [isaacsim.exp.base-5.1.0] (/home/sysadmin/lab/robotodo/.conda/lib/python3.11/site-packages/isaacsim/apps/isaacsim.exp.base.kit)
#  Synced registries:
# 	 - kit/default         : found 2549 packages
# 	 - kit/sdk             : found 714 packages
# 	 - kit/community       : found 475 packages
# [1374.816s] [ext: isaacsim.asset.importer.mjcf-2.5.8] shutdown
# [1375.220s] [ext: isaacsim.asset.importer.urdf-2.4.19] shutdown
# [1375.598s] [ext: isaacsim.core.experimental.utils-0.2.0] shutdown
# [1375.821s] [ext: isaacsim.core.throttling-2.1.10] shutdown
# [1376.050s] [ext: isaacsim.examples.browser-0.1.12] shutdown
# [1376.609s] [ext: isaacsim.gui.components-1.1.9] shutdown
# [1376.895s] [ext: isaacsim.gui.content_browser-0.1.9] shutdown
# [1377.121s] [ext: omni.kit.property.isaac-1.0.6] shutdown
# [1377.568s] [ext: isaacsim.gui.property-1.1.3] shutdown
# [1378.006s] [ext: omni.isaac.lula-4.0.6] shutdown
# [1378.286s] [ext: isaacsim.robot_motion.lula-4.0.8] shutdown
# [1378.738s] [ext: isaacsim.test.docstring-1.1.0] shutdown
# [1378.982s] Pulling extension: `isaacsim.core.throttling-2.1.10` from the registry.
# [1380.491s] Extension: `isaacsim.core.throttling-2.1.10` was installed.
# [1380.491s] Pulling extension: `isaacsim.gui.content_browser-0.1.9` from the registry.
# [1380.937s] Extension: `isaacsim.gui.content_browser-0.1.9` was installed.
# [1380.937s] Pulling extension: `isaacsim.gui.components-1.1.9` from the registry.
# [1380.949s] Extension: `isaacsim.gui.components-1.1.9` was installed.
# [1380.949s] Pulling extension: `isaacsim.examples.browser-0.1.12` from the registry.
# [1382.160s] Extension: `isaacsim.examples.browser-0.1.12` was installed.
# [1382.160s] Pulling extension: `isaacsim.asset.importer.urdf-2.4.19` from the registry.
# [1382.169s] Extension: `isaacsim.asset.importer.urdf-2.4.19` was installed.
# [1382.169s] Pulling extension: `isaacsim.core.experimental.utils-0.2.0` from the registry.
# [1382.589s] Extension: `isaacsim.core.experimental.utils-0.2.0` was installed.
# [1382.589s] Pulling extension: `isaacsim.asset.importer.mjcf-2.5.8` from the registry.
# [1383.488s] Extension: `isaacsim.asset.importer.mjcf-2.5.8` was installed.
# [1383.494s] [ext: isaacsim.gui.property-1.1.3] startup
# [1383.500s] [ext: omni.kit.property.isaac-1.0.6] startup
# [1383.503s] [ext: isaacsim.core.throttling-2.1.10] startup
# [1383.507s] [ext: isaacsim.gui.content_browser-0.1.9] startup
# [1383.511s] [ext: isaacsim.gui.components-1.1.9] startup
# [1383.518s] [ext: isaacsim.examples.browser-0.1.12] startup
# [1383.558s] [ext: isaacsim.asset.importer.urdf-2.4.19] startup
# [1383.602s] [ext: isaacsim.robot_motion.lula-4.0.8] startup
# [1383.608s] [ext: omni.isaac.lula-4.0.6] startup
# [1383.614s] [ext: isaacsim.test.docstring-1.1.0] startup
# [1383.616s] [ext: isaacsim.core.experimental.utils-0.2.0] startup
# [1383.618s] [ext: isaacsim.asset.importer.mjcf-2.5.8] startup
